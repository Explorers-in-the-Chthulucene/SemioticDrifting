# %%
import pandas as pd
import os

cwd = os.getcwd()
print(cwd)

entities_df = pd.read_csv("./ch_7/ch_7.entities", delimiter="\t")
#entities_df = pd.read_csv("ChthuluceneDR/Chthulucene.entities", delimiter="\t")
#supersense_df = pd.read_csv("../distant_reading/ChthuluceneDR/Chthulucene.supersense", delimiter="\t")
tokens_df = pd.read_csv("./ch_7/ch_7.tokens", delimiter="\t")
#df = df.sort_values(by = ["COREF"], ascending = True )
#df = df.query("COREF == 354")

#supersense_df = supersense_df.query("supersense_category == 'noun.event'")
#df = entities_df.sort_values(by=["COREF"], ascending=True)
#df[300:350]


#tokens_df = tokens_df.query("sentence_ID == 0" and "sentence_ID == 1")

#char_id in .quotes == COREF in .entities
#entities_df[50:100]
tokens_df[50:100]
# Out:
# c:\Users\ghiot\Documents\GitHub\SemioticDrifting\script\BookNLP
#     paragraph_ID  sentence_ID  token_ID_within_sentence  \
# 50             0            3                         3
# 51             0            3                         4
# 52             0            3                         5
# 53             0            3                         6
# 54             0            3                         7
# 55             0            3                         8
# 56             0            3                         9
# 57             0            3                        10
# 58             0            3                        11
# 59             0            3                        12
# 60             0            3                        13
# 61             0            3                        14
# 62             0            3                        15
# 63             0            3                        16
# 64             0            3                        17
# 65             0            3                        18
# 66             0            3                        19
# 67             0            3                        20
# 68             0            3                        21
# 69             0            3                        22
# 70             0            3                        23
# 71             0            3                        24
# 72             0            3                        25
# 73             0            4                         0
# 74             0            4                         1
# 75             0            4                         2
# 76             0            4                         3
# 77             0            4                         4
# 78             0            4                         5
# 79             0            4                         6
# 80             0            4                         7
# 81             0            4                         8
# 82             0            4                         9
# 83             0            4                        10
# 84             0            4                        11
# 85             0            4                        12
# 86             0            4                        13
# 87             0            4                        14
# 88             0            4                        15
# 89             0            4                        16
# 90             0            4                        17
# 91             0            4                        18
# 92             0            4                        19
# 93             0            4                        20
# 94             0            5                         0
# 95             0            5                         1
# 96             0            5                         2
# 97             0            5                         3
# 98             0            5                         4
# 99             0            5                         5
#
#     token_ID_within_document          word         lemma  byte_onset  \
# 50                        50             a             a         238
# 51                        51       singing       singing         240
# 52                        52     blackbird     blackbird         248
# 53                        53           one           one         258
# 54                        54       morning       morning         262
# 55                        55             —             —         269
# 56                        56             a             a         270
# 57                        57        living          live         272
# 58                        58     blackbird     blackbird         279
# 59                        59       outside       outside         289
# 60                        60           her           her         297
# 61                        61    particular    particular         301
# 62                        62        window        window         312
# 63                        63             —             —         318
# 64                        64           and           and         319
# 65                        65          that          that         323
# 66                        66           way           way         328
# 67                        67       learned         learn         332
# 68                        68          what          what         340
# 69                        69    importance    importance         345
# 70                        70        sounds         sound         356
# 71                        71          like          like         363
# 72                        72             .             .         367
# 73                        73           She           she         369
# 74                        74        thinks         think         373
# 75                        75            in            in         380
# 76                        76    attunement    attunement         383
# 77                        77          with          with         394
# 78                        78         those         those         399
# 79                        79           she           she         405
# 80                        80        thinks         think         409
# 81                        81          with          with         416
# 82                        82             —             —         420
# 83                        83   recursively   recursively         421
# 84                        84             ,             ,         432
# 85                        85   inventively   inventively         434
# 86                        86             ,             ,         445
# 87                        87  relentlessly  relentlessly         447
# 88                        88             —             —         459
# 89                        89          with          with         460
# 90                        90           joy           joy         465
# 91                        91           and           and         469
# 92                        92         verve         verve         473
# 93                        93             .             .         478
# 94                        94           She           she         480
# 95                        95       studies         study         484
# 96                        96           how           how         492
# 97                        97        beings         being         496
# 98                        98        render        render         503
# 99                        99          each          each         510
#
#     byte_offset POS_tag fine_POS_tag dependency_relation  syntactic_head_ID  \
# 50          239     DET           DT                 det                 52
# 51          247    NOUN           NN            compound                 52
# 52          257    NOUN           NN                pobj                 49
# 53          261     NUM           CD              nummod                 54
# 54          269    NOUN           NN            npadvmod                 48
# 55          270   PUNCT            :               punct                 54
# 56          271     DET           DT                 det                 58
# 57          278    VERB          VBG                amod                 58
# 58          288    NOUN           NN               appos                 54
# 59          296     ADP           IN                prep                 58
# 60          300    PRON         PRP$                poss                 62
# 61          311     ADJ           JJ                amod                 62
# 62          318    NOUN           NN                pobj                 59
# 63          319   PUNCT            :               punct                 58
# 64          322   CCONJ           CC                  cc                 48
# 65          327     DET           DT                 det                 66
# 66          331    NOUN           NN               nsubj                 67
# 67          339    VERB          VBD                conj                 48
# 68          344     DET          WDT                 det                 69
# 69          355    NOUN           NN               nsubj                 70
# 70          362    VERB          VBZ               ccomp                 67
# 71          367     ADP           IN                prep                 70
# 72          368   PUNCT            .               punct                 67
# 73          372    PRON          PRP               nsubj                 74
# 74          379    VERB          VBZ                ROOT                 74
# 75          382     ADP           IN                prep                 74
# 76          393    NOUN           NN                pobj                 75
# 77          398     ADP           IN                prep                 74
# 78          404    PRON           DT                pobj                 77
# 79          408    PRON          PRP               nsubj                 80
# 80          415    VERB          VBZ               relcl                 78
# 81          420     ADP           IN                prep                 80
# 82          421   PUNCT            :               punct                 81
# 83          432     ADV           RB              advmod                 85
# 84          433   PUNCT            ,               punct                 83
# 85          445     ADV           RB              advmod                 80
# 86          446   PUNCT            ,               punct                 85
# 87          459     ADV           RB              advmod                 85
# 88          460   PUNCT            :               punct                 85
# 89          464     ADP           IN                prep                 85
# 90          468    NOUN           NN                pobj                 89
# 91          472   CCONJ           CC                  cc                 90
# 92          478    NOUN           NN                conj                 90
# 93          479   PUNCT            .               punct                 74
# 94          483    PRON          PRP               nsubj                 95
# 95          491    VERB          VBZ                ROOT                 95
# 96          495   SCONJ          WRB              advmod                 98
# 97          502    NOUN          NNS               nsubj                 98
# 98          509    VERB          VBP               ccomp                 95
# 99          514     DET           DT                 det                100
#
#     event
# 50      O
# 51  EVENT
# 52      O
# 53      O
# 54      O
# 55      O
# 56      O
# 57      O
# 58      O
# 59      O
# 60      O
# 61      O
# 62      O
# 63      O
# 64      O
# 65      O
# 66      O
# 67      O
# 68      O
# 69      O
# 70      O
# 71      O
# 72      O
# 73      O
# 74      O
# 75      O
# 76      O
# 77      O
# 78      O
# 79      O
# 80      O
# 81      O
# 82      O
# 83      O
# 84      O
# 85      O
# 86      O
# 87      O
# 88      O
# 89      O
# 90      O
# 91      O
# 92      O
# 93      O
# 94      O
# 95      O
# 96      O
# 97      O
# 98      O
# 99      O

# %%
dep = set(tokens_df["dependency_relation"])
print(dep) #PER GPE LOC ORG
# Out:
# {'acl', 'pcomp', 'ccomp', 'expl', 'compound', 'preconj', 'case', 'acomp', 'nsubjpass', 'dobj', 'ROOT', 'amod', 'agent', 'attr', 'prep', 'quantmod', 'xcomp', 'nummod', 'dep', 'nsubj', 'cc', 'neg', 'appos', 'conj', 'oprd', 'aux', 'npadvmod', 'dative', 'mark', 'prt', 'advmod', 'nmod', 'relcl', 'auxpass', 'punct', 'det', 'csubj', 'advcl', 'poss', 'predet', 'pobj'}

# %%
import json

with open ("../distant_reading/ChthuluceneDR/Chthulucene.book", "r") as f:
    book_data = json.load(f)
book_data.keys()
# Out:
# dict_keys(['characters'])

# %%
len(book_data["characters"])
# Out:
# 543

# %%
book_data["characters"][0].keys()
# agent: the action a char does
# patient: the actions done to the char
# mod: modifiers of the char, like adjectives
# poss: what is possessed by the chracter (in a broad sense)
# id: unique identifier
# g: gender inference
# count: number of times the char appears in the text
# mentions:  how the char is referenced in the text
# Out:
# dict_keys(['agent', 'patient', 'mod', 'poss', 'id', 'g', 'count', 'mentions'])

# %%
agent = book_data["characters"][0]["agent"][:1]
book_data["characters"][0]["patient"][:1]
book_data["characters"][0]["mod"][:1]
book_data["characters"][0]["poss"][:1]
book_data["characters"][0]["id"]
book_data["characters"][0]["g"]
book_data["characters"][0]["count"]
book_data["characters"][0]["mentions"].keys()
# Out:
# dict_keys(['proper', 'common', 'pronoun'])

# %%
book_data["characters"][0]["poss"][:10]
# Out:
# [{'w': 'readers', 'i': 808},
#  {'w': 'experts', 'i': 1359},
#  {'w': 'partners', 'i': 1990},
#  {'w': 'companions', 'i': 2028},
#  {'w': 'companion', 'i': 2919},
#  {'w': 'Cayenne', 'i': 2923},
#  {'w': 'multispecies', 'i': 3649},
#  {'w': 'stories', 'i': 4011},
#  {'w': 'equation', 'i': 4026},
#  {'w': 'critters', 'i': 4455}]

# %%
book_data["characters"][0]["mentions"]["pronoun"]
# what is 'w' and 'i' and 'c' and 'n'??
# Out:
# [{'c': 182, 'n': 'I'},
#  {'c': 79, 'n': 'my'},
#  {'c': 67, 'n': 'me'},
#  {'c': 24, 'n': 'My'},
#  {'c': 2, 'n': 'myself'}]
