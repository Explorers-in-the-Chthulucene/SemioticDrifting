# %%
import pandas as pd
import os

cwd = os.getcwd()
print(cwd)

entities_df = pd.read_csv("./ch_7/ch_7.entities", delimiter="\t")
#entities_df = pd.read_csv("ChthuluceneDR/Chthulucene.entities", delimiter="\t")
#supersense_df = pd.read_csv("../distant_reading/ChthuluceneDR/Chthulucene.supersense", delimiter="\t")
tokens_df = pd.read_csv("./ch_7/ch_7.tokens", delimiter="\t")
#df = df.sort_values(by = ["COREF"], ascending = True )
#df = df.query("COREF == 354")

#supersense_df = supersense_df.query("supersense_category == 'noun.event'")
#df = entities_df.sort_values(by=["COREF"], ascending=True)
#df[300:350]


#tokens_df = tokens_df.query("sentence_ID == 0" and "sentence_ID == 1")

#char_id in .quotes == COREF in .entities
tokens_df[:50]
# Out:
# c:\Users\ghiot\Documents\GitHub\SemioticDrifting\script\BookNLP
#     paragraph_ID  sentence_ID  token_ID_within_sentence  \
# 0              0            0                         0
# 1              0            0                         1
# 2              0            0                         2
# 3              0            0                         3
# 4              0            0                         4
# 5              0            0                         5
# 6              0            0                         6
# 7              0            0                         7
# 8              0            0                         8
# 9              0            0                         9
# 10             0            0                        10
# 11             0            0                        11
# 12             0            1                         0
# 13             0            1                         1
# 14             0            1                         2
# 15             0            1                         3
# 16             0            1                         4
# 17             0            1                         5
# 18             0            1                         6
# 19             0            1                         7
# 20             0            2                         0
# 21             0            2                         1
# 22             0            2                         2
# 23             0            2                         3
# 24             0            2                         4
# 25             0            2                         5
# 26             0            2                         6
# 27             0            2                         7
# 28             0            2                         8
# 29             0            2                         9
# 30             0            2                        10
# 31             0            2                        11
# 32             0            2                        12
# 33             0            2                        13
# 34             0            2                        14
# 35             0            2                        15
# 36             0            2                        16
# 37             0            2                        17
# 38             0            2                        18
# 39             0            2                        19
# 40             0            2                        20
# 41             0            2                        21
# 42             0            2                        22
# 43             0            2                        23
# 44             0            2                        24
# 45             0            2                        25
# 46             0            2                        26
# 47             0            3                         0
# 48             0            3                         1
# 49             0            3                         2
#
#     token_ID_within_document      word     lemma  byte_onset  byte_offset  \
# 0                          0  Vinciane  Vinciane           0            8
# 1                          1   Despret   Despret           9           16
# 2                          2    thinks     think          17           23
# 3                          3         -         -          23           24
# 4                          4      with      with          24           28
# 5                          5     other     other          29           34
# 6                          6    beings     being          35           41
# 7                          7         ,         ,          41           42
# 8                          8     human     human          43           48
# 9                          9       and       and          49           52
# 10                        10       not       not          53           56
# 11                        11         .         .          56           57
# 12                        12      That      that          58           62
# 13                        13        is        be          63           65
# 14                        14         a         a          66           67
# 15                        15      rare      rare          68           72
# 16                        16       and       and          73           76
# 17                        17  precious  precious          77           85
# 18                        18  vocation  vocation          86           94
# 19                        19         .         .          94           95
# 20                        20  Vocation  vocation          96          104
# 21                        21         :         :         104          105
# 22                        22   calling      call         106          113
# 23                        23         ,         ,         113          114
# 24                        24   calling      call         115          122
# 25                        25      with      with         123          127
# 26                        26         ,         ,         127          128
# 27                        27    called      call         129          135
# 28                        28        by        by         136          138
# 29                        29         ,         ,         138          139
# 30                        30   calling      call         140          147
# 31                        31        as        as         148          150
# 32                        32        if        if         151          153
# 33                        33       the       the         154          157
# 34                        34     world     world         158          163
# 35                        35  mattered    matter         164          172
# 36                        36         ,         ,         172          173
# 37                        37   calling      call         174          181
# 38                        38       out       out         182          185
# 39                        39         ,         ,         185          186
# 40                        40     going        go         187          192
# 41                        41       too       too         193          196
# 42                        42       far       far         197          200
# 43                        43         ,         ,         200          201
# 44                        44     going        go         202          207
# 45                        45  visiting     visit         208          216
# 46                        46         .         .         216          217
# 47                        47   Despret   Despret         218          225
# 48                        48  listened    listen         226          234
# 49                        49        to        to         235          237
#
#    POS_tag fine_POS_tag dependency_relation  syntactic_head_ID event
# 0    PROPN          NNP            compound                  1     O
# 1    PROPN          NNP               nsubj                  2     O
# 2     VERB          VBZ                ROOT                  2     O
# 3    PUNCT         HYPH               punct                  2     O
# 4      ADP           IN                prep                  2     O
# 5      ADJ           JJ                amod                  6     O
# 6     NOUN          NNS                pobj                  4     O
# 7    PUNCT            ,               punct                  6     O
# 8      ADJ           JJ                conj                  6     O
# 9    CCONJ           CC                  cc                  8     O
# 10    PART           RB                conj                  8     O
# 11   PUNCT            .               punct                  2     O
# 12    PRON           DT               nsubj                 13     O
# 13     AUX          VBZ                ROOT                 13     O
# 14     DET           DT                 det                 18     O
# 15     ADJ           JJ                amod                 18     O
# 16   CCONJ           CC                  cc                 15     O
# 17     ADJ           JJ                conj                 15     O
# 18    NOUN           NN                attr                 13     O
# 19   PUNCT            .               punct                 13     O
# 20    NOUN           NN                ROOT                 20     O
# 21   PUNCT            :               punct                 20     O
# 22    VERB          VBG                 acl                 20     O
# 23   PUNCT            ,               punct                 22     O
# 24    VERB          VBG               advcl                 22     O
# 25     ADP           IN                prep                 24     O
# 26   PUNCT            ,               punct                 24     O
# 27    VERB          VBN               advcl                 24     O
# 28     ADP           IN                prep                 27     O
# 29   PUNCT            ,               punct                 27     O
# 30    VERB          VBG                conj                 27     O
# 31   SCONJ           IN                mark                 35     O
# 32   SCONJ           IN                mark                 35     O
# 33     DET           DT                 det                 34     O
# 34    NOUN           NN               nsubj                 35     O
# 35    VERB          VBD               advcl                 30     O
# 36   PUNCT            ,               punct                 22     O
# 37    VERB          VBG               advcl                 22     O
# 38     ADP           RP                 prt                 37     O
# 39   PUNCT            ,               punct                 37     O
# 40    VERB          VBG               advcl                 37     O
# 41     ADV           RB              advmod                 42     O
# 42     ADV           RB              advmod                 40     O
# 43   PUNCT            ,               punct                 22     O
# 44    VERB          VBG                conj                 22     O
# 45    VERB          VBG               xcomp                 44     O
# 46   PUNCT            .               punct                 20     O
# 47   PROPN          NNP               nsubj                 48     O
# 48    VERB          VBD                ROOT                 48     O
# 49     ADP           IN                prep                 48     O

# %%
import json

with open ("../distant_reading/ChthuluceneDR/Chthulucene.book", "r") as f:
    book_data = json.load(f)
book_data.keys()
# Out:
# dict_keys(['characters'])

# %%
len(book_data["characters"])
# Out:
# 543

# %%
book_data["characters"][0].keys()
# agent: the action a char does
# patient: the actions done to the char
# mod: modifiers of the char, like adjectives
# poss: what is possessed by the chracter (in a broad sense)
# id: unique identifier
# g: gender inference
# count: number of times the char appears in the text
# mentions:  how the char is referenced in the text
# Out:
# dict_keys(['agent', 'patient', 'mod', 'poss', 'id', 'g', 'count', 'mentions'])

# %%
agent = book_data["characters"][0]["agent"][:1]
book_data["characters"][0]["patient"][:1]
book_data["characters"][0]["mod"][:1]
book_data["characters"][0]["poss"][:1]
book_data["characters"][0]["id"]
book_data["characters"][0]["g"]
book_data["characters"][0]["count"]
book_data["characters"][0]["mentions"].keys()
# Out:
# dict_keys(['proper', 'common', 'pronoun'])

# %%
book_data["characters"][0]["poss"][:10]
# Out:
# [{'w': 'readers', 'i': 808},
#  {'w': 'experts', 'i': 1359},
#  {'w': 'partners', 'i': 1990},
#  {'w': 'companions', 'i': 2028},
#  {'w': 'companion', 'i': 2919},
#  {'w': 'Cayenne', 'i': 2923},
#  {'w': 'multispecies', 'i': 3649},
#  {'w': 'stories', 'i': 4011},
#  {'w': 'equation', 'i': 4026},
#  {'w': 'critters', 'i': 4455}]

# %%
book_data["characters"][0]["mentions"]["pronoun"]
# what is 'w' and 'i' and 'c' and 'n'??
# Out:
# [{'c': 182, 'n': 'I'},
#  {'c': 79, 'n': 'my'},
#  {'c': 67, 'n': 'me'},
#  {'c': 24, 'n': 'My'},
#  {'c': 2, 'n': 'myself'}]
