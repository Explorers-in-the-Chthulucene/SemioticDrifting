# %%
import pandas as pd
import os

cwd = os.getcwd()
print(cwd)

df = pd.read_csv("../distant_reading/ChthuluceneDR/ChthuluceneCopy.tokens", delimiter="\t")
df = df.query("event == 'EVENT'")
df
# Out:
# c:\Users\ghiot\Documents\GitHub\SemioticDrifting\script
#      paragraph_ID  sentence_ID  token_ID_within_sentence  \
# 389             2           15                         1
# 834             3           36                         3
# 846             3           36                        15
#
#      token_ID_within_document      word  lemma  byte_onset  byte_offset  \
# 389                       403      hear   hear        2016         2020
# 834                       848  plucking  pluck        4334         4342
# 846                       860       try    try        4399         4402
#
#     POS_tag fine_POS_tag dependency_relation  syntactic_head_ID  event
# 389    VERB          VBP                ROOT                403  EVENT
# 834    VERB          VBG               advcl                860  EVENT
# 846    VERB          VBP                ROOT                860  EVENT
