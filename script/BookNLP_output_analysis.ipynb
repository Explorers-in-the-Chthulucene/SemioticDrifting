# %%
import pandas as pd
import os

cwd = os.getcwd()
print(cwd)

quotes_df = pd.read_csv("../distant_reading/ChthuluceneDR/Chthulucene.quotes", delimiter="\t")
entities_df = pd.read_csv("../distant_reading/ChthuluceneDR/Chthulucene.entities", delimiter="\t")
supersense_df = pd.read_csv("../distant_reading/ChthuluceneDR/Chthulucene.supersense", delimiter="\t")
tokens_df = pd.read_csv("../distant_reading/ChthuluceneDR/Chthulucene.tokens", delimiter="\t")
#df = df.sort_values(by = ["COREF"], ascending = True )
#df = df.query("COREF == 354")

supersense_df = supersense_df.query("supersense_category == 'noun.event'")
#df = entities_df.sort_values(by=["COREF"], ascending=True)
#df[300:350]

tokens_df = tokens_df.query("word == 'me'")
tokens_df

#char_id in .quotes == COREF in .entities
# Out:
# c:\Users\ghiot\Documents\GitHub\SemioticDrifting\script
#        paragraph_ID  sentence_ID  token_ID_within_sentence  \
# 890               2           31                        10
# 976               2           33                        30
# 2465              8          123                         5
# 4707             17          264                         5
# 4717             17          264                        15
# 5264             21          283                         4
# 5448             21          286                        16
# 5461             21          287                         9
# 6135             25          318                        32
# 6542             25          329                        14
# 11977            55          653                        39
# 14759            69          789                        22
# 16232            81          933                         6
# 16865            95         1045                         7
# 16892            99         1073                        14
# 16898            99         1073                        26
# 16904            99         1073                        39
# 17050           110         1227                        16
# 17178           111         1232                         3
# 17714           122         1374                        84
# 18957           130         1484                         3
# 19100           130         1488                         4
# 19370           132         1497                         6
# 20842           137         1640                         9
# 20935           137         1648                        19
# 21852           137         1701                        10
# 22062           137         1705                        16
# 22093           137         1706                         5
#
#        token_ID_within_document word lemma  byte_onset  byte_offset POS_tag  \
# 890                         897   me     I        4839         4841    PRON
# 976                         983   me     I        5305         5307    PRON
# 2465                       3796   me     I       20767        20769    PRON
# 4707                       8072   me     I       43983        43985    PRON
# 4717                       8082   me     I       44032        44034    PRON
# 5264                       8635   me     I       47011        47013    PRON
# 5448                       8828   me     I       48014        48016    PRON
# 5461                       8841   me     I       48080        48082    PRON
# 6135                       9814   me     I       53352        53354    PRON
# 6542                      10243   me     I       55443        55445    PRON
# 11977                     19757   me     I      105696       105698    PRON
# 14759                     24192   me     I      131354       131356    PRON
# 16232                     28781   me     I      156087       156089    PRON
# 16865                     32067   me     I      174524       174526    PRON
# 16892                     32824   me     I      178705       178707    PRON
# 16898                     32836   me     I      178743       178745    PRON
# 16904                     32849   me     I      178784       178786    PRON
# 17050                     38266   me     I      208351       208353    PRON
# 17178                     38396   me     I      208998       209000    PRON
# 17714                     42873   me     I      233074       233076    PRON
# 18957                     46072   me     I      249293       249295    PRON
# 19100                     46219   me     I      249997       249999    PRON
# 19370                     46493   me     I      251443       251445    PRON
# 20842                     50281   me     I      271863       271865    PRON
# 20935                     50486   me     I      272925       272927    PRON
# 21852                     52030   me     I      280740       280742    PRON
# 22062                     52243   me     I      281878       281880    PRON
# 22093                     52274   me     I      282033       282035    PRON
#
#       fine_POS_tag dependency_relation  syntactic_head_ID event
# 890            PRP                dobj                896     O
# 976            PRP                dobj                982     O
# 2465           PRP                pobj               3795     O
# 4707           PRP               nsubj               8073     O
# 4717           PRP                dobj               8081     O
# 5264           PRP                dobj               8634     O
# 5448           PRP                dobj               8827     O
# 5461           PRP                dobj               8840     O
# 6135           PRP                pobj               9813     O
# 6542           PRP                dobj              10242     O
# 11977          PRP                pobj              19756     O
# 14759          PRP                pobj              24191     O
# 16232          PRP                pobj              28780     O
# 16865          PRP                pobj              32066     O
# 16892          PRP                pobj              32823     O
# 16898          PRP                pobj              32835     O
# 16904          PRP                pobj              32848     O
# 17050          PRP                pobj              38265     O
# 17178          PRP                dobj              38395     O
# 17714          PRP                pobj              42872     O
# 18957          PRP                dobj              46071     O
# 19100          PRP                dobj              46218     O
# 19370          PRP                dobj              46492     O
# 20842          PRP                dobj              50280     O
# 20935          PRP                pobj              50485     O
# 21852          PRP                conj              52028     O
# 22062          PRP                dobj              52242     O
# 22093          PRP                dobj              52273     O

# %%
import json

with open ("../distant_reading/ChthuluceneDR/Chthulucene.book", "r") as f:
    book_data = json.load(f)
book_data.keys()
# Out:
# dict_keys(['characters'])

# %%
len(book_data["characters"])
# Out:
# 543

# %%
book_data["characters"][0].keys()
# agent: the action a char does
# patient: the actions done to the char
# mod: modifiers of the char, like adjectives
# poss: what is possessed by the chracter (in a broad sense)
# id: unique identifier
# g: gender inference
# count: number of times the char appears in the text
# mentions:  how the char is referenced in the text
# Out:
# dict_keys(['agent', 'patient', 'mod', 'poss', 'id', 'g', 'count', 'mentions'])

# %%
agent = book_data["characters"][0]["agent"][:1]
book_data["characters"][0]["patient"][:1]
book_data["characters"][0]["mod"][:1]
book_data["characters"][0]["poss"][:1]
book_data["characters"][0]["id"]
book_data["characters"][0]["g"]
book_data["characters"][0]["count"]
book_data["characters"][0]["mentions"].keys()
# Out:
# dict_keys(['proper', 'common', 'pronoun'])

# %%
book_data["characters"][0]["poss"][:10]
# Out:
# [{'w': 'readers', 'i': 808},
#  {'w': 'experts', 'i': 1359},
#  {'w': 'partners', 'i': 1990},
#  {'w': 'companions', 'i': 2028},
#  {'w': 'companion', 'i': 2919},
#  {'w': 'Cayenne', 'i': 2923},
#  {'w': 'multispecies', 'i': 3649},
#  {'w': 'stories', 'i': 4011},
#  {'w': 'equation', 'i': 4026},
#  {'w': 'critters', 'i': 4455}]

# %%
book_data["characters"][0]["mentions"]["pronoun"]
# what is 'w' and 'i' and 'c' and 'n'??
# Out:
# [{'c': 182, 'n': 'I'},
#  {'c': 79, 'n': 'my'},
#  {'c': 67, 'n': 'me'},
#  {'c': 24, 'n': 'My'},
#  {'c': 2, 'n': 'myself'}]
