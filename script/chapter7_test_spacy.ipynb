# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import networkx as nx

import matplotlib.pyplot as plt
import spacy
from spacy.tokens import DocBin

# %%
nlp = spacy.load("en_core_web_sm")

# %%
#NOW WE'RE READY TO BEGIN WITH NAMED ENTITY RECOGNITION
#*STEPS*
#Tokenize the script into a list of sentences. Label each sentence by the label of the characters
#Define the window size, i.e. how far two sentences are apart from each other. We propose here a network visualization in which each character is represented by a node connected with the characters that appear in the same scenes. 
# Resuming: 
#Two characters are connected if they appear in the same scene.
#Their size and color intensity are proportional to their weighted degree (degree=number of connections)
#The ‘network density’ measures how close the graph is to complete. A complete graph (100%) has all possible edges between its nodes.

# %%
script= 'CHAP_7.txt'
script_text = open(script, encoding='utf-8').read()
script_doc = nlp(script_text)

# %%
# quick test - identified entities
displacy.render(script_doc[0:2000], style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vinciane Despret
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  thinks-with other beings, human and not. That is a rare and precious vocation. Vocation: calling, calling with, called by, calling as if the world mattered, calling out, going too far, going visiting.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Despret
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  listened to a singing blackbird
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# —a living blackbird outside her particular window—and that way learned what importance sounds like. She thinks in attunement with those she thinks with—recursively, inventively, relentlessly—with joy and verve. She studies how beings render each other capable in actual encounters, and she theorizes— makes cogently available—that kind of theory and method.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Despret
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is not interested in thinking by discovering the stupidities of others, or by reducing the field of attention to prove a point. Her kind of thinking enlarges, even invents, the competencies of all the players, including herself, such that the domain of ways of being and knowing dilates, expands, adds both ontological and epistemological possibilities, proposes and enacts what was not there before. That is her worlding practice. She is a philosopher and a scientist who is allergic to denunciation and hungry for discovery, needy for what must be known and built together, with and for earthly beings, living, dead, and yet to come. Referring both to her own practice for observing scientists and also to the practices of ethologist
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thelma Rowell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  observing her Soay sheep,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Despret
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  affirmed “a particular epistemological position to which I am committed, one that I call a virtue: the virtue of politeness.” In every sense,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Despret
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s cultivation of politeness is a curious practice. She trains her whole being, not just her imagination, in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arendt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s words, “to go visiting.” Visiting is not an easy practice; it demands the ability to find others actively interesting, even or especially others most people already claim to know all too completely, to ask questions that one’s interlocutors truly find interesting, to cultivate the wild virtue of curiosity, to retune one’s ability to sense and respond—and to do all this politely! What is this sort of politeness? It sounds more than a little risky. Curiosity always leads its practitioners a bit too far off the path, and that way lie stories. The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  and most important thing at risk in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Despret
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s practice is an approach that assumes that beings have pre-established natures and abilities that are simply put into play in an encounter. Rather,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Despret
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s sort of politeness does the energetic work of holding open the possibility that surprises are in store, that something interesting is about to happen, but only if one cultivates the virtue of letting those one visits intra-actively shape what occurs. They are not who/what we expected to visit, and we are not who/what were anticipated either. Visiting is a subjectand object-making dance, and the choreographer is a trickster. Asking questions comes to mean both asking what another finds intriguing and also how learning to engage that changes everybody in unforeseeable ways. Good questions come only to a polite inquirer, especially a polite inquirer provoked by a singing blackbird. With good questions, even or especially mistakes and misunderstandings can become interesting. This is not so much a question of manners, but of epistemology and ontology, and of method alert to off-the-beaten-path practices. At the least, this sort of politeness is not what Miss
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Manners
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  purveys in her advice column. There are so many examples of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Despret
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  learning and teaching polite inquiry. Perhaps the most famous is her visit to the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.3

# %%
token_list = []
for token in script_doc:
    token_list.append(token.text)
print(token_list)
# Out:
# ['Vinciane', 'Despret', 'thinks', '-', 'with', 'other', 'beings', ',', 'human', 'and', 'not', '.', 'That', 'is', 'a', 'rare', 'and', 'precious', 'vocation', '.', 'Vocation', ':', 'calling', ',', 'calling', 'with', ',', 'called', 'by', ',', 'calling', 'as', 'if', 'the', 'world', 'mattered', ',', 'calling', 'out', ',', 'going', 'too', 'far', ',', 'going', 'visiting', '.', 'Despret', 'listened', 'to', 'a', 'singing', 'blackbird', 'one', 'morning', '—', 'a', 'living', 'blackbird', 'outside', 'her', 'particular', 'window', '—', 'and', 'that', 'way', 'learned', 'what', 'importance', 'sounds', 'like', '.', 'She', 'thinks', 'in', 'attunement', 'with', 'those', 'she', 'thinks', 'with', '—', 'recursively', ',', 'inventively', ',', 'relentlessly', '—', 'with', 'joy', 'and', 'verve', '.', 'She', 'studies', 'how', 'beings', 'render', 'each', 'other', 'capable', 'in', 'actual', 'encounters', ',', 'and', 'she', 'theorizes', '—', 'makes', 'cogently', 'available', '—', 'that', 'kind', 'of', 'theory', 'and', 'method', '.', 'Despret', 'is', 'not', 'interested', 'in', 'thinking', 'by', 'discovering', 'the', 'stupidities', 'of', 'others', ',', 'or', 'by', 'reducing', 'the', 'field', 'of', 'attention', 'to', 'prove', 'a', 'point', '.', 'Her', 'kind', 'of', 'thinking', 'enlarges', ',', 'even', 'invents', ',', 'the', 'competencies', 'of', 'all', 'the', 'players', ',', 'including', 'herself', ',', 'such', 'that', 'the', 'domain', 'of', 'ways', 'of', 'being', 'and', 'knowing', 'dilates', ',', 'expands', ',', 'adds', 'both', 'ontological', 'and', 'epistemological', 'possibilities', ',', 'proposes', 'and', 'enacts', 'what', 'was', 'not', 'there', 'before', '.', 'That', 'is', 'her', 'worlding', 'practice', '.', 'She', 'is', 'a', 'philosopher', 'and', 'a', 'scientist', 'who', 'is', 'allergic', 'to', 'denunciation', 'and', 'hungry', 'for', 'discovery', ',', 'needy', 'for', 'what', 'must', 'be', 'known', 'and', 'built', 'together', ',', 'with', 'and', 'for', 'earthly', 'beings', ',', 'living', ',', 'dead', ',', 'and', 'yet', 'to', 'come', '.', 'Referring', 'both', 'to', 'her', 'own', 'practice', 'for', 'observing', 'scientists', 'and', 'also', 'to', 'the', 'practices', 'of', 'ethologist', 'Thelma', 'Rowell', 'observing', 'her', 'Soay', 'sheep', ',', 'Despret', 'affirmed', '“', 'a', 'particular', 'epistemological', 'position', 'to', 'which', 'I', 'am', 'committed', ',', 'one', 'that', 'I', 'call', 'a', 'virtue', ':', 'the', 'virtue', 'of', 'politeness', '.', '”', 'In', 'every', 'sense', ',', 'Despret', '’s', 'cultivation', 'of', 'politeness', 'is', 'a', 'curious', 'practice', '.', 'She', 'trains', 'her', 'whole', 'being', ',', 'not', 'just', 'her', 'imagination', ',', 'in', 'Arendt', '’s', 'words', ',', '“', 'to', 'go', 'visiting', '.', '”', 'Visiting', 'is', 'not', 'an', 'easy', 'practice', ';', 'it', 'demands', 'the', 'ability', 'to', 'find', 'others', 'actively', 'interesting', ',', 'even', 'or', 'especially', 'others', 'most', 'people', 'already', 'claim', 'to', 'know', 'all', 'too', 'completely', ',', 'to', 'ask', 'questions', 'that', 'one', '’s', 'interlocutors', 'truly', 'find', 'interesting', ',', 'to', 'cultivate', 'the', 'wild', 'virtue', 'of', 'curiosity', ',', 'to', 'retune', 'one', '’s', 'ability', 'to', 'sense', 'and', 'respond', '—', 'and', 'to', 'do', 'all', 'this', 'politely', '!', 'What', 'is', 'this', 'sort', 'of', 'politeness', '?', 'It', 'sounds', 'more', 'than', 'a', 'little', 'risky', '.', 'Curiosity', 'always', 'leads', 'its', 'practitioners', 'a', 'bit', 'too', 'far', 'off', 'the', 'path', ',', 'and', 'that', 'way', 'lie', 'stories', '.', 'The', 'first', 'and', 'most', 'important', 'thing', 'at', 'risk', 'in', 'Despret', '’s', 'practice', 'is', 'an', 'approach', 'that', 'assumes', 'that', 'beings', 'have', 'pre', '-', 'established', 'natures', 'and', 'abilities', 'that', 'are', 'simply', 'put', 'into', 'play', 'in', 'an', 'encounter', '.', 'Rather', ',', 'Despret', '’s', 'sort', 'of', 'politeness', 'does', 'the', 'energetic', 'work',  ...

# %%
# Create list of word tokens
token_list = []
for token in script_doc:
    token_list.append(token.text)
print(token_list)
# Out:
# ['Vinciane', 'Despret', 'thinks', '-', 'with', 'other', 'beings', ',', 'human', 'and', 'not', '.', 'That', 'is', 'a', 'rare', 'and', 'precious', 'vocation', '.', 'Vocation', ':', 'calling', ',', 'calling', 'with', ',', 'called', 'by', ',', 'calling', 'as', 'if', 'the', 'world', 'mattered', ',', 'calling', 'out', ',', 'going', 'too', 'far', ',', 'going', 'visiting', '.', 'Despret', 'listened', 'to', 'a', 'singing', 'blackbird', 'one', 'morning', '—', 'a', 'living', 'blackbird', 'outside', 'her', 'particular', 'window', '—', 'and', 'that', 'way', 'learned', 'what', 'importance', 'sounds', 'like', '.', 'She', 'thinks', 'in', 'attunement', 'with', 'those', 'she', 'thinks', 'with', '—', 'recursively', ',', 'inventively', ',', 'relentlessly', '—', 'with', 'joy', 'and', 'verve', '.', 'She', 'studies', 'how', 'beings', 'render', 'each', 'other', 'capable', 'in', 'actual', 'encounters', ',', 'and', 'she', 'theorizes', '—', 'makes', 'cogently', 'available', '—', 'that', 'kind', 'of', 'theory', 'and', 'method', '.', 'Despret', 'is', 'not', 'interested', 'in', 'thinking', 'by', 'discovering', 'the', 'stupidities', 'of', 'others', ',', 'or', 'by', 'reducing', 'the', 'field', 'of', 'attention', 'to', 'prove', 'a', 'point', '.', 'Her', 'kind', 'of', 'thinking', 'enlarges', ',', 'even', 'invents', ',', 'the', 'competencies', 'of', 'all', 'the', 'players', ',', 'including', 'herself', ',', 'such', 'that', 'the', 'domain', 'of', 'ways', 'of', 'being', 'and', 'knowing', 'dilates', ',', 'expands', ',', 'adds', 'both', 'ontological', 'and', 'epistemological', 'possibilities', ',', 'proposes', 'and', 'enacts', 'what', 'was', 'not', 'there', 'before', '.', 'That', 'is', 'her', 'worlding', 'practice', '.', 'She', 'is', 'a', 'philosopher', 'and', 'a', 'scientist', 'who', 'is', 'allergic', 'to', 'denunciation', 'and', 'hungry', 'for', 'discovery', ',', 'needy', 'for', 'what', 'must', 'be', 'known', 'and', 'built', 'together', ',', 'with', 'and', 'for', 'earthly', 'beings', ',', 'living', ',', 'dead', ',', 'and', 'yet', 'to', 'come', '.', 'Referring', 'both', 'to', 'her', 'own', 'practice', 'for', 'observing', 'scientists', 'and', 'also', 'to', 'the', 'practices', 'of', 'ethologist', 'Thelma', 'Rowell', 'observing', 'her', 'Soay', 'sheep', ',', 'Despret', 'affirmed', '“', 'a', 'particular', 'epistemological', 'position', 'to', 'which', 'I', 'am', 'committed', ',', 'one', 'that', 'I', 'call', 'a', 'virtue', ':', 'the', 'virtue', 'of', 'politeness', '.', '”', 'In', 'every', 'sense', ',', 'Despret', '’s', 'cultivation', 'of', 'politeness', 'is', 'a', 'curious', 'practice', '.', 'She', 'trains', 'her', 'whole', 'being', ',', 'not', 'just', 'her', 'imagination', ',', 'in', 'Arendt', '’s', 'words', ',', '“', 'to', 'go', 'visiting', '.', '”', 'Visiting', 'is', 'not', 'an', 'easy', 'practice', ';', 'it', 'demands', 'the', 'ability', 'to', 'find', 'others', 'actively', 'interesting', ',', 'even', 'or', 'especially', 'others', 'most', 'people', 'already', 'claim', 'to', 'know', 'all', 'too', 'completely', ',', 'to', 'ask', 'questions', 'that', 'one', '’s', 'interlocutors', 'truly', 'find', 'interesting', ',', 'to', 'cultivate', 'the', 'wild', 'virtue', 'of', 'curiosity', ',', 'to', 'retune', 'one', '’s', 'ability', 'to', 'sense', 'and', 'respond', '—', 'and', 'to', 'do', 'all', 'this', 'politely', '!', 'What', 'is', 'this', 'sort', 'of', 'politeness', '?', 'It', 'sounds', 'more', 'than', 'a', 'little', 'risky', '.', 'Curiosity', 'always', 'leads', 'its', 'practitioners', 'a', 'bit', 'too', 'far', 'off', 'the', 'path', ',', 'and', 'that', 'way', 'lie', 'stories', '.', 'The', 'first', 'and', 'most', 'important', 'thing', 'at', 'risk', 'in', 'Despret', '’s', 'practice', 'is', 'an', 'approach', 'that', 'assumes', 'that', 'beings', 'have', 'pre', '-', 'established', 'natures', 'and', 'abilities', 'that', 'are', 'simply', 'put', 'into', 'play', 'in', 'an', 'encounter', '.', 'Rather', ',', 'Despret', '’s', 'sort', 'of', 'politeness', 'does', 'the', 'energetic', 'work',  ...

# %%
for word in script_doc:
    print(word.text,word.pos_)
# Out:
# Vinciane PROPN
# Despret PROPN
# thinks VERB
# - PUNCT
# with ADP
# other ADJ
# beings NOUN
# , PUNCT
# human NOUN
# and CCONJ
# not PART
# . PUNCT
# That DET
# is AUX
# a DET
# rare ADJ
# and CCONJ
# precious ADJ
# vocation NOUN
# . PUNCT
# Vocation NOUN
# : PUNCT
# calling VERB
# , PUNCT
# calling VERB
# with ADP
# , PUNCT
# called VERB
# by ADP
# , PUNCT
# calling VERB
# as SCONJ
# if SCONJ
# the DET
# world NOUN
# mattered VERB
# , PUNCT
# calling VERB
# out ADP
# , PUNCT
# going VERB
# too ADV
# far ADV
# , PUNCT
# going VERB
# visiting VERB
# . PUNCT
# Despret PROPN
# listened VERB
# to ADP
# a DET
# singing NOUN
# blackbird NOUN
# one NUM
# morning NOUN
# — PUNCT
# a DET
# living VERB
# blackbird NOUN
# outside ADP
# her DET
# particular ADJ
# window NOUN
# — PUNCT
# and CCONJ
# that DET
# way NOUN
# learned VERB
# what DET
# importance NOUN
# sounds VERB
# like SCONJ
# . PUNCT
# She PRON
# thinks VERB
# in ADP
# attunement NOUN
# with ADP
# those DET
# she PRON
# thinks VERB
# with ADP
# — PUNCT
# recursively ADV
# , PUNCT
# inventively ADV
# , PUNCT
# relentlessly ADV
# — PUNCT
# with ADP
# joy NOUN
# and CCONJ
# verve VERB
# . PUNCT
# She PRON
# studies VERB
# how ADV
# beings NOUN
# render VERB
# each DET
# other ADJ
# capable ADJ
# in ADP
# actual ADJ
# encounters NOUN
# , PUNCT
# and CCONJ
# she PRON
# theorizes VERB
# — PUNCT
# makes VERB
# cogently ADV
# available ADJ
# — PUNCT
# that DET
# kind NOUN
# of ADP
# theory NOUN
# and CCONJ
# method NOUN
# . PUNCT
# Despret PROPN
# is AUX
# not PART
# interested ADJ
# in ADP
# thinking VERB
# by ADP
# discovering VERB
# the DET
# stupidities NOUN
# of ADP
# others NOUN
# , PUNCT
# or CCONJ
# by ADP
# reducing VERB
# the DET
# field NOUN
# of ADP
# attention NOUN
# to PART
# prove VERB
# a DET
# point NOUN
# . PUNCT
# Her DET
# kind NOUN
# of ADP
# thinking VERB
# enlarges NOUN
# , PUNCT
# even ADV
# invents NOUN
# , PUNCT
# the DET
# competencies NOUN
# of ADP
# all DET
# the DET
# players NOUN
# , PUNCT
# including VERB
# herself PRON
# , PUNCT
# such ADJ
# that SCONJ
# the DET
# domain NOUN
# of ADP
# ways NOUN
# of ADP
# being AUX
# and CCONJ
# knowing VERB
# dilates NOUN
# , PUNCT
# expands VERB
# , PUNCT
# adds VERB
# both CCONJ
# ontological ADJ
# and CCONJ
# epistemological ADJ
# possibilities NOUN
# , PUNCT
# proposes VERB
# and CCONJ
# enacts VERB
# what PRON
# was AUX
# not PART
# there ADV
# before ADV
# . PUNCT
# That DET
# is AUX
# her DET
# worlding NOUN
# practice NOUN
# . PUNCT
# She PRON
# is AUX
# a DET
# philosopher NOUN
# and CCONJ
# a DET
# scientist NOUN
# who PRON
# is AUX
# allergic ADJ
# to ADP
# denunciation NOUN
# and CCONJ
# hungry ADJ
# for ADP
# discovery NOUN
# , PUNCT
# needy ADJ
# for ADP
# what PRON
# must VERB
# be AUX
# known VERB
# and CCONJ
# built VERB
# together ADV
# , PUNCT
# with ADP
# and CCONJ
# for ADP
# earthly ADJ
# beings NOUN
# , PUNCT
# living VERB
# , PUNCT
# dead ADJ
# , PUNCT
# and CCONJ
# yet ADV
# to PART
# come VERB
# . PUNCT
# Referring VERB
# both DET
# to ADP
# her DET
# own ADJ
# practice NOUN
# for ADP
# observing VERB
# scientists NOUN
# and CCONJ
# also ADV
# to ADP
# the DET
# practices NOUN
# of ADP
# ethologist ADJ
# Thelma PROPN
# Rowell PROPN
# observing VERB
# her DET
# Soay PROPN
# sheep NOUN
# , PUNCT
# Despret PROPN
# affirmed VERB
# “ PUNCT
# a DET
# particular ADJ
# epistemological ADJ
# position NOUN
# to PART
# which DET
# I PRON
# am AUX
# committed ADJ
# , PUNCT
# one NOUN
# that DET
# I PRON
# call VERB
# a DET
# virtue NOUN
# : PUNCT
# the DET
# virtue NOUN
# of ADP
# politeness NOUN
# . PUNCT
# ” PUNCT
# In ADP
# every DET
# sense NOUN
# , PUNCT
# Despret PROPN
# ’s PART
# cultivation NOUN
# of ADP
# politeness NOUN
# is AUX
# a DET
# curious ADJ
# practice NOUN
# . PUNCT
# She PRON
# trains VERB
# her DET
# whole ADJ
# being NOUN
# , PUNCT
# not PART
# just ADV
# her DET
# imagination NOUN
# , PUNCT
# in ADP
# Arendt PROPN
# ’s PART
# words NOUN
# , PUNCT
# “ PUNCT
# to PART
# go VERB
# visiting VERB
# . PUNCT
# ” PUNCT
# Visiting VERB
# is AUX
# not PART
# an DET
# easy ADJ
# practice NOUN
# ; PUNCT
# it PRON
# demands VERB
# the DET
# ability NOUN
# to PART
# find VERB
# others NOUN
# actively ADV
# interesting ADJ
# , PUNCT
# even ADV
# or CCONJ
# especially ADV
# others NOUN
# most ADJ
# people NOUN
# already ADV
# claim VERB
# to PART
# know VERB
# all ADV
# too ADV
# completely ADV
# , PUNCT
# to PART
# ask VERB
# questions NOUN
# that SCONJ
# one NOUN
# ’s PART
# interlocutors NOUN
# truly ADV
# find VERB
# interesting ADJ
# , PUNCT
# to PART
# cultivate VERB
# the DET
# wild ADJ
# virtue NOUN
# of ADP
# curiosity NOUN
# , PUNCT
# to ADP
# retune VERB
# one NUM
# ’s PUNCT
# ability NOUN
# to PART
# sense VERB
# and CCONJ
# respond VERB
# — PUNCT
# and CCONJ
# to PART
# do AUX
# all DET
# this DET
# politely ADV
# ! PUNCT
# What PRON
# is AUX
# this DET
# sort NOUN
# of ADP
# politeness NOUN
# ? PUNCT
# It PRON
# sounds VERB
# more ADJ
# than SCONJ
# a DET
# little ADJ
# risky ADJ
# . PUNCT
# Curiosity PROPN
# always ADV
# leads VERB
# its DET
# practitioners NOUN
# a DET
# bit NOUN
# too ADV
# far ADV
# off ADP
# the DET
# path NOUN
# , PUNCT
# and CCONJ
# that DET
# way NOUN
# lie VERB
# stories NOUN
# . PUNCT
# The DET
# first ADJ
# and CCONJ
# most ADV
# important ADJ
# thing NOUN
# at ADP
# risk NOUN
# in ADP
# Despret PROPN
# ’s PART
# practice NOUN
# is AUX
# an DET
# approach NOUN
# that DET
# assumes VERB
# that SCONJ
# beings NOUN
# have AUX
# pre VERB
# - ADJ
# established ADJ
# natures NOUN
# and CCONJ
# abilities NOUN
# that DET
# are AUX
# simply ADV
# put VERB
# into ADP
# play NOUN
# in ADP
# an DET
# encounter NOUN
# . PUNCT
# Rather ADV
# , PUNCT
# Despret PROPN
# ’s PART
# sort NOUN
# of ADP
# politeness NOUN
# does AUX
# the DET
# energetic ADJ
# work NOUN
# of ADP
# holding VERB
# open VERB
# the DET
# possibility NOUN
# that SCONJ
# surprises NOUN
# are AUX
# in ADP
# store NOUN
# , PUNCT
# that SCONJ
# something PRON
# interesting ADJ
# is AUX
# about ADJ
# to PART
# happen VERB
# , PUNCT
# but CCONJ
# only ADV
# if SCONJ
# one PRON
# cultivates VERB
# the DET
# virtue NOUN
# of ADP
# letting VERB
# those DET
# one NUM
# visits VERB
# intra ADJ
# - PUNCT
# actively ADV
# shape VERB
# what PRON
# occurs VERB
# . PUNCT
# They PRON
# are AUX
# not PART
# who PRON
# / SYM
# what PRON
# we PRON
# expected VERB
# to PART
# visit VERB
# , PUNCT
# and CCONJ
# we PRON
# are AUX
# not PART
# who PRON
# / SYM
# what PRON
# were AUX
# anticipated VERB
# either ADV
# . PUNCT
# Visiting VERB
# is AUX
# a DET
# subjectand NOUN
# object NOUN
# - PUNCT
# making VERB
# dance NOUN
# , PUNCT
# and CCONJ
# the DET
# choreographer NOUN
# is AUX
# a DET
# trickster NOUN
# . PUNCT
# Asking VERB
# questions NOUN
# comes VERB
# to PART
# mean VERB
# both DET
# asking VERB
# what PRON
# another DET
# finds VERB
# intriguing ADJ
# and CCONJ
# also ADV
# how ADV
# learning VERB
# to PART
# engage VERB
# that SCONJ
# changes VERB
# everybody PRON
# in ADP
# unforeseeable ADJ
# ways NOUN
# . PUNCT
# Good ADJ
# questions NOUN
# come VERB
# only ADV
# to ADP
# a DET
# polite ADJ
# inquirer NOUN
# , PUNCT
# especially ADV
# a DET
# polite ADJ
# inquirer NOUN
# provoked VERB
# by ADP
# a DET
# singing NOUN
# blackbird NOUN
# . PUNCT
# With ADP
# good ADJ
# questions NOUN
# , PUNCT
# even ADV
# or CCONJ
# especially ADV
# mistakes NOUN
# and CCONJ
# misunderstandings NOUN
# can VERB
# become VERB
# interesting ADJ
# . PUNCT
# This DET
# is AUX
# not PART
# so ADV
# much ADV
# a DET
# question NOUN
# of ADP
# manners NOUN
# , PUNCT
# but CCONJ
# of ADP
# epistemology NOUN
# and CCONJ
# ontology NOUN
# , PUNCT
# and CCONJ
# of ADP
# method NOUN
# alert NOUN
# to ADP
# off ADP
# - PUNCT
# the DET
# - PUNCT
# beaten VERB
# - PUNCT
# path NOUN
# practices NOUN
# . PUNCT
# At ADP
# the DET
# least ADJ
# , PUNCT
# this DET
# sort NOUN
# of ADP
# politeness NOUN
# is AUX
# not PART
# what PRON
# Miss PROPN
# Manners PROPN
# purveys NOUN
# in ADP
# her DET
# advice NOUN
# column NOUN
# . PUNCT
# There PRON
# are AUX
# so ADV
# many ADJ
# examples NOUN
# of ADP
# Despret ADJ
# learning NOUN
# and CCONJ
# teaching VERB
# polite ADJ
# inquiry NOUN
# . PUNCT
# Perhaps ADV
# the DET
# most ADV
# famous ADJ
# is AUX
# her DET
# visit NOUN
# to ADP
# the DET
# Negev PROPN
# desert NOUN
# field NOUN
# site NOUN
# of ADP
# the DET
# Israeli ADJ
# ornithologist NOUN
# Amotz PROPN
# Zahavi PROPN
# , PUNCT
# where ADV
# she PRON
# encountered VERB
# Arabian ADJ
# babblers NOUN
# who PRON
# defied VERB
# orthodox ADJ
# accounts NOUN
# of ADP
# what PRON
# birds NOUN
# should VERB
# be AUX
# doing VERB
# , PUNCT
# even ADV
# as SCONJ
# the DET
# scientists NOUN
# also ADV
# acted VERB
# off ADP
# - PUNCT
# script NOUN
# scientifically ADV
# . PUNCT
# Specifically ADV
# , PUNCT
# Zahavi PROPN
# asked VERB
# in ADP
# excruciating VERB
# detail NOUN
# , PUNCT
# what PRON
# matters VERB
# to ADP
# babblers NOUN
# ? PUNCT
# He PRON
# could VERB
# not PART
# do AUX
# good ADJ
# science NOUN
# otherwise ADV
# . PUNCT
# The DET
# babblers NOUN
# ’ PART
# practices NOUN
# of ADP
# altruism NOUN
# were AUX
# off ADP
# the DET
# charts NOUN
# , PUNCT
# and CCONJ
# they PRON
# seemed VERB
# to PART
# do AUX
# it PRON
# , PUNCT
# according VERB
# to ADP
# Zahavi PROPN
# , PUNCT
# for ADP
# reasons NOUN
# of ADP
# competitive ADJ
# prestige NOUN
# not PART
# well ADV
# accounted VERB
# for ADP
# by ADP
# theories NOUN
# like SCONJ
# kin NOUN
# selection NOUN
# . PUNCT
# Zahavi PROPN
# let VERB
# the DET
# babblers NOUN
# be AUX
# interesting ADJ
# ; PUNCT
# he PRON
# asked VERB
# them PRON
# interesting ADJ
# questions NOUN
# ; PUNCT
# he PRON
# saw VERB
# them PRON
# dance VERB
# . PUNCT
# “ PUNCT
# Not PART
# only ADV
# were AUX
# these DET
# birds NOUN
# described VERB
# as SCONJ
# dancing VERB
# together ADV
# in ADP
# the DET
# morning NOUN
# sunrise NOUN
# , PUNCT
# not PART
# only ADV
# were AUX
# they PRON
# eager ADJ
# to PART
# offer VERB
# presents NOUN
# to ADP
# one NUM
# another DET
# , PUNCT
# not PART
# only ADV
# would VERB
# they PRON
# take VERB
# pride NOUN
# in ADP
# caring VERB
# for ADP
# each DET
# other ADJ
# ’s PART
# nestlings NOUN
# or CCONJ
# in ADP
# defending VERB
# an DET
# endangered VERB
# comrade NOUN
# , PUNCT
# but CCONJ
# also ADV
# , PUNCT
# according VERB
# to ADP
# Zahavi PROPN
# ’s PART
# depiction NOUN
# , PUNCT
# their DET
# relations NOUN
# relied VERB
# on ADP
# trust NOUN
# . PUNCT
# ” PUNCT
# What PRON
# Despret PROPN
# tells VERB
# us PRON
# she PRON
# came VERB
# to PART
# know VERB
# is AUX
# that SCONJ
# the DET
# specific ADJ
# practices NOUN
# of ADP
# observation NOUN
# , PUNCT
# narration NOUN
# , PUNCT
# and CCONJ
# the DET
# liveliness NOUN
# of ADP
# the DET
# birds NOUN
# were AUX
# far ADV
# from ADP
# independent ADJ
# of ADP
# each DET
# other ADJ
# . PUNCT
# This DET
# was AUX
# not PART
# just ADV
# a DET
# question NOUN
# of ADP
# worldviews NOUN
# and CCONJ
# related ADJ
# theories NOUN
# shaping VERB
# research NOUN
# design NOUN
# and CCONJ
# interpretations NOUN
# , PUNCT
# or CCONJ
# of ADP
# any DET
# other ADJ
# purely ADV
# discursive ADJ
# effect NOUN
# . PUNCT
# What PRON
# scientists NOUN
# actually ADV
# do AUX
# in ADP
# the DET
# field NOUN
# affects VERB
# the DET
# ways NOUN
# “ PUNCT
# animals NOUN
# see VERB
# their DET
# scientists NOUN
# seeing VERB
# them PRON
# ” PUNCT
# and CCONJ
# therefore ADV
# how ADV
# the DET
# animals NOUN
# respond VERB
# . PUNCT
# In ADP
# a DET
# strong ADJ
# sense NOUN
# , PUNCT
# observers NOUN
# and CCONJ
# birds NOUN
# rendered VERB
# each DET
# other ADJ
# capable ADJ
# in ADP
# ways NOUN
# not PART
# written VERB
# into ADP
# preexisting NOUN
# scripts NOUN
# , PUNCT
# but CCONJ
# invented VERB
# or CCONJ
# provoked VERB
# , PUNCT
# more ADV
# than SCONJ
# simply ADV
# shown VERB
# , PUNCT
# in ADP
# practical ADJ
# research NOUN
# . PUNCT
# Birds NOUN
# and CCONJ
# scientists NOUN
# were AUX
# in ADP
# dynamic ADJ
# , PUNCT
# moving VERB
# relations NOUN
# of ADP
# attunement NOUN
# . PUNCT
# The DET
# behavior NOUN
# of ADP
# birds NOUN
# and CCONJ
# their DET
# observers NOUN
# were AUX
# made VERB
# , PUNCT
# but CCONJ
# not PART
# made VERB
# up ADP
# . PUNCT
# Stories NOUN
# are AUX
# essential ADJ
# , PUNCT
# but CCONJ
# are AUX
# never ADV
# “ PUNCT
# mere ADJ
# ” PUNCT
# stories NOUN
# . PUNCT
# Zahavi PROPN
# seemed VERB
# intent ADJ
# on ADP
# making VERB
# experiments NOUN
# with ADP
# rather ADV
# than SCONJ
# on ADP
# babblers NOUN
# . PUNCT
# He PRON
# was AUX
# trying VERB
# to PART
# look VERB
# at ADP
# the DET
# world NOUN
# with ADP
# the DET
# babblers NOUN
# rather ADV
# than SCONJ
# at ADP
# them PRON
# , PUNCT
# a DET
# very ADV
# demanding ADJ
# practice NOUN
# . PUNCT
# And CCONJ
# the DET
# same ADJ
# demands NOUN
# were AUX
# made VERB
# of ADP
# Despret PROPN
# , PUNCT
# who PRON
# came VERB
# to PART
# watch VERB
# scientists NOUN
# but CCONJ
# ended VERB
# up ADP
# in ADP
# a DET
# much ADV
# more ADV
# complex ADJ
# tangle NOUN
# of ADP
# practices NOUN
# . PUNCT
# Birds NOUN
# and CCONJ
# scientists NOUN
# do AUX
# something PRON
# , PUNCT
# and CCONJ
# they PRON
# do AUX
# it PRON
# together ADV
# . PUNCT
# They PRON
# become VERB
# - PUNCT
# with ADP
# each DET
# other ADJ
# . PUNCT
# The DET
# world NOUN
# in ADP
# the DET
# southern ADJ
# Israeli ADJ
# desert NOUN
# was AUX
# composed VERB
# by ADP
# adding VERB
# competencies NOUN
# to PART
# engage VERB
# competencies NOUN
# , PUNCT
# adding VERB
# perspectives VERB
# to PART
# engage VERB
# perspectives NOUN
# , PUNCT
# adding VERB
# subjectivities NOUN
# to PART
# engage VERB
# subjectivities NOUN
# , PUNCT
# adding VERB
# versions NOUN
# to PART
# understand VERB
# versions NOUN
# . PUNCT
# In ADP
# short ADJ
# , PUNCT
# this DET
# science NOUN
# worked VERB
# by ADP
# addition NOUN
# , PUNCT
# not PART
# subtraction NOUN
# . PUNCT
# Worlds NOUN
# enlarged VERB
# ; PUNCT
# the DET
# babblers NOUN
# and CCONJ
# the DET
# scientists NOUN
# — PUNCT
# Despret PROPN
# included VERB
# — PUNCT
# inhabited VERB
# a DET
# world NOUN
# of ADP
# propositions NOUN
# not PART
# available ADJ
# before ADV
# . PUNCT
# “ PUNCT
# Both DET
# humans NOUN
# and CCONJ
# babblers NOUN
# create VERB
# narratives NOUN
# , PUNCT
# rather ADV
# than SCONJ
# just ADV
# telling VERB
# them PRON
# . PUNCT
# They PRON
# create VERB
# / SYM
# disclose VERB
# new ADJ
# scripts NOUN
# . PUNCT
# ” PUNCT
# Good ADJ
# questions NOUN
# were AUX
# posed VERB
# ; PUNCT
# surprising ADJ
# answers NOUN
# made VERB
# the DET
# world NOUN
# richer ADJ
# . PUNCT
# Visiting VERB
# might VERB
# be AUX
# risky ADJ
# , PUNCT
# but CCONJ
# it PRON
# is AUX
# definitely ADV
# not PART
# boring ADJ
# . PUNCT
# Despret PROPN
# ’s PART
# work NOUN
# is AUX
# full ADJ
# of ADP
# literal ADJ
# collaborations NOUN
# , PUNCT
# with ADP
# people NOUN
# and CCONJ
# with ADP
# animals NOUN
# , PUNCT
# not PART
# simply ADV
# metaphors NOUN
# of ADP
# thinking VERB
# with ADP
# each DET
# other ADJ
# . PUNCT
# I PRON
# admit VERB
# I PRON
# am AUX
# drawn VERB
# most ADV
# by ADP
# the DET
# collaborations NOUN
# that DET
# entangle VERB
# people NOUN
# , PUNCT
# critters NOUN
# , PUNCT
# and CCONJ
# apparatuses NOUN
# . PUNCT
# No DET
# wonder NOUN
# that SCONJ
# Despret PROPN
# ’s PART
# work NOUN
# with ADP
# sociologist NOUN
# Jocelyne PROPN
# Porcher PROPN
# and CCONJ
# the DET
# farmers NOUN
# , PUNCT
# pigs NOUN
# , PUNCT
# and CCONJ
# cows NOUN
# in ADP
# their DET
# care NOUN
# sustains VERB
# me PRON
# . PUNCT
# Despret PROPN
# and CCONJ
# Porcher PROPN
# visited VERB
# cow NOUN
# and CCONJ
# pig NOUN
# breeders NOUN
# on ADP
# nonindustrial ADJ
# French ADJ
# farms NOUN
# , PUNCT
# where ADV
# the DET
# humans NOUN
# and CCONJ
# animals NOUN
# lived VERB
# in ADP
# daily ADJ
# interaction NOUN
# that DET
# led VERB
# sober ADJ
# , PUNCT
# nonromantic ADJ
# , PUNCT
# working VERB
# breeders NOUN
# to PART
# say VERB
# such ADJ
# things NOUN
# as SCONJ
# , PUNCT
# “ PUNCT
# We PRON
# do AUX
# n’t PART
# stop VERB
# talking VERB
# with ADP
# our DET
# animals NOUN
# . PUNCT
# ” PUNCT
# The DET
# question NOUN
# that DET
# led VERB
# Despret PROPN
# and CCONJ
# Porcher PROPN
# to ADP
# the DET
# farmers NOUN
# circled VERB
# around ADP
# their DET
# efforts NOUN
# to PART
# think VERB
# through ADP
# what PRON
# it PRON
# means VERB
# to PART
# claim VERB
# that SCONJ
# these DET
# domestic ADJ
# food NOUN
# - PUNCT
# producing VERB
# animals NOUN
# are AUX
# working VERB
# , PUNCT
# and CCONJ
# working VERB
# with ADP
# their DET
# people NOUN
# . PUNCT
# The DET
# first ADJ
# difficulty NOUN
# , PUNCT
# not PART
# surprisingly ADV
# , PUNCT
# was AUX
# to PART
# figure VERB
# out ADP
# how ADV
# to PART
# ask VERB
# questions NOUN
# that DET
# interested VERB
# the DET
# breeders NOUN
# , PUNCT
# that DET
# engaged VERB
# them PRON
# in ADP
# their DET
# conversations NOUN
# and CCONJ
# labors NOUN
# with ADP
# their DET
# animals NOUN
# . PUNCT
# It PRON
# was AUX
# decidedly ADV
# not PART
# interesting ADJ
# to ADP
# the DET
# breeders NOUN
# to PART
# ask VERB
# how ADV
# animals NOUN
# and CCONJ
# people NOUN
# are AUX
# the DET
# same ADJ
# or CCONJ
# different ADJ
# in ADP
# general ADJ
# . PUNCT
# These DET
# are AUX
# people NOUN
# who PRON
# make VERB
# particular ADJ
# animals NOUN
# live VERB
# and CCONJ
# die VERB
# and CCONJ
# who PRON
# live VERB
# , PUNCT
# and CCONJ
# die VERB
# , PUNCT
# by ADP
# them PRON
# . PUNCT
# The DET
# task NOUN
# was AUX
# to PART
# engage VERB
# these DET
# breeders NOUN
# in ADP
# constructing VERB
# the DET
# questions NOUN
# that DET
# mattered VERB
# to ADP
# them PRON
# . PUNCT
# The DET
# breeders NOUN
# incessantly ADV
# “ PUNCT
# uprooted VERB
# ” PUNCT
# the DET
# researchers NOUN
# ’ PART
# questions NOUN
# to PART
# address VERB
# the DET
# queries NOUN
# that DET
# concerned VERB
# them PRON
# in ADP
# their DET
# work NOUN
# . PUNCT
# The DET
# story NOUN
# has AUX
# many ADJ
# turns NOUN
# , PUNCT
# but CCONJ
# what PRON
# interested VERB
# me PRON
# most ADV
# was AUX
# the DET
# insistence NOUN
# of ADP
# the DET
# breeders NOUN
# that DET
# their DET
# animals NOUN
# “ PUNCT
# know VERB
# what PRON
# we PRON
# want VERB
# , PUNCT
# but CCONJ
# we PRON
# , PUNCT
# we PRON
# do AUX
# n’t PART
# know VERB
# what PRON
# they PRON
# want VERB
# . PUNCT
# ” PUNCT
# Figuring VERB
# out ADP
# what PRON
# their DET
# animals NOUN
# want VERB
# , PUNCT
# so SCONJ
# that SCONJ
# people NOUN
# and CCONJ
# cows NOUN
# could VERB
# together ADV
# accomplish VERB
# successful ADJ
# breeding NOUN
# , PUNCT
# was AUX
# the DET
# fundamental ADJ
# conjoined VERB
# work NOUN
# of ADP
# the DET
# farm NOUN
# . PUNCT
# Farmers NOUN
# bad ADJ
# at ADP
# listening VERB
# to ADP
# their DET
# animals NOUN
# , PUNCT
# bad ADJ
# at ADP
# talking VERB
# to ADP
# them PRON
# , PUNCT
# and CCONJ
# bad ADJ
# at ADP
# responding VERB
# were AUX
# not PART
# good ADJ
# farmers NOUN
# in ADP
# their DET
# peers NOUN
# ’ PART
# estimation NOUN
# . PUNCT
# The DET
# animals NOUN
# paid VERB
# attention NOUN
# to ADP
# their DET
# farmers NOUN
# ; PUNCT
# paying VERB
# equally ADV
# effective ADJ
# attention NOUN
# to ADP
# the DET
# cows NOUN
# and CCONJ
# pigs NOUN
# was AUX
# the DET
# job NOUN
# of ADP
# good ADJ
# breeders NOUN
# . PUNCT
# This DET
# is AUX
# an DET
# extension NOUN
# of ADP
# subjectivities NOUN
# for ADP
# both DET
# people NOUN
# and CCONJ
# critters NOUN
# , PUNCT
# “ PUNCT
# becoming VERB
# what PRON
# the DET
# other ADJ
# suggests VERB
# to ADP
# you PRON
# , PUNCT
# accepting VERB
# a DET
# proposal NOUN
# of ADP
# subjectivity NOUN
# , PUNCT
# acting VERB
# in ADP
# the DET
# manner NOUN
# in ADP
# which DET
# the DET
# other ADJ
# addresses VERB
# you PRON
# , PUNCT
# actualizing VERB
# and CCONJ
# verifying VERB
# this DET
# proposal NOUN
# , PUNCT
# in ADP
# the DET
# sense NOUN
# of ADP
# rendering VERB
# it PRON
# true ADJ
# . PUNCT
# ” PUNCT
# The DET
# result NOUN
# is AUX
# bringing VERB
# into ADP
# being AUX
# animals NOUN
# that SCONJ
# nourish NOUN
# humans NOUN
# , PUNCT
# and CCONJ
# humans NOUN
# that DET
# nourish VERB
# animals NOUN
# . PUNCT
# Living NOUN
# and CCONJ
# dying VERB
# are AUX
# both DET
# in ADP
# play NOUN
# . PUNCT
# “ PUNCT
# Working VERB
# together ADV
# ” PUNCT
# in ADP
# this DET
# kind NOUN
# of ADP
# daily ADJ
# interaction NOUN
# of ADP
# labor NOUN
# , PUNCT
# conversation NOUN
# , PUNCT
# and CCONJ
# attention NOUN
# seems VERB
# to ADP
# me PRON
# to PART
# be AUX
# the DET
# right ADJ
# idiom NOUN
# . PUNCT
# Continually ADV
# hungry ADJ
# for ADP
# more ADJ
# of ADP
# Despret PROPN
# ’s PART
# visiting VERB
# with ADP
# critters NOUN
# , PUNCT
# their DET
# people NOUN
# , PUNCT
# and CCONJ
# their DET
# apparatuses NOUN
# — PUNCT
# hungry ADJ
# for ADP
# more ADJ
# of ADP
# her DET
# elucidations NOUN
# of ADP
# “ PUNCT
# anthropo PROPN
# - PUNCT
# zoo NOUN
# - PUNCT
# genesis NOUN
# ” PUNCT
# — PUNCT
# I PRON
# have AUX
# a DET
# hard ADJ
# time NOUN
# feeling VERB
# satisfied ADJ
# with ADP
# only ADJ
# human ADJ
# people NOUN
# on ADP
# the DET
# menu NOUN
# . PUNCT
# That DET
# prejudice NOUN
# took VERB
# a DET
# tumble NOUN
# when ADV
# I PRON
# read VERB
# Women NOUN
# Who PRON
# Make VERB
# a DET
# Fuss NOUN
# : PUNCT
# The DET
# Unfaithful PROPN
# Daughters PROPN
# of ADP
# Virginia PROPN
# Woolf PROPN
# , PUNCT
# which DET
# Isabelle PROPN
# Stengers PROPN
# and CCONJ
# Vinciane PROPN
# Despret PROPN
# wrote VERB
# together ADV
# with ADP
# an DET
# extraordinary ADJ
# collective NOUN
# of ADP
# bumptious ADJ
# women NOUN
# . PUNCT
# “ PUNCT
# Think VERB
# we PRON
# must VERB
# ! PUNCT
# ” PUNCT
# cries VERB
# this DET
# book NOUN
# , PUNCT
# in ADP
# concert NOUN
# with ADP
# the DET
# famous ADJ
# line NOUN
# from ADP
# Virginia PROPN
# Woolf PROPN
# ’s PART
# Three PROPN
# Guineas PROPN
# . PUNCT
# In ADP
# Western ADJ
# worlds NOUN
# , PUNCT
# and CCONJ
# elsewhere ADV
# too ADV
# , PUNCT
# women NOUN
# have AUX
# hardly ADV
# been AUX
# included VERB
# in ADP
# the DET
# patrilines NOUN
# of ADP
# thinking NOUN
# , PUNCT
# most ADV
# certainly ADV
# including VERB
# the DET
# patrilines NOUN
# making VERB
# decisions NOUN
# for ADP
# ( PUNCT
# yet ADV
# another DET
# ) PUNCT
# war NOUN
# . PUNCT
# Why ADV
# should VERB
# Virginia PROPN
# Woolf PROPN
# , PUNCT
# or CCONJ
# any DET
# other ADJ
# woman NOUN
# , PUNCT
# or CCONJ
# men NOUN
# for ADP
# that DET
# matter NOUN
# , PUNCT
# be AUX
# faithful ADJ
# to ADP
# such ADJ
# patrilines NOUN
# and CCONJ
# their DET
# demands NOUN
# for ADP
# sacrifice NOUN
# ? PUNCT
# Infidelity PROPN
# seems VERB
# the DET
# least ADJ
# we PRON
# should VERB
# demand VERB
# of ADP
# ourselves PRON
# ! PUNCT
# This DET
# all DET
# matters VERB
# , PUNCT
# but CCONJ
# the DET
# question NOUN
# in ADP
# this DET
# book NOUN
# is AUX
# not PART
# precisely ADV
# that DET
# , PUNCT
# but CCONJ
# rather ADV
# what PRON
# thinking NOUN
# can VERB
# possibly ADV
# mean VERB
# in ADP
# the DET
# civilization NOUN
# in ADP
# which DET
# we PRON
# find VERB
# ourselves PRON
# . PUNCT
# “ PUNCT
# But CCONJ
# how ADV
# do AUX
# we PRON
# take VERB
# back ADV
# up ADP
# a DET
# collective ADJ
# adventure NOUN
# that DET
# is AUX
# multiple ADJ
# and CCONJ
# ceaselessly ADV
# reinvented VERB
# , PUNCT
# not PART
# on ADP
# an DET
# individual ADJ
# basis NOUN
# , PUNCT
# but CCONJ
# in ADP
# a DET
# way NOUN
# that DET
# passes VERB
# the DET
# baton PROPN
# , PUNCT
# that DET
# is AUX
# to PART
# say VERB
# , PUNCT
# affirms VERB
# new ADJ
# givens NOUN
# and CCONJ
# new ADJ
# unknowns NOUN
# ? PUNCT
# ” PUNCT
# We PRON
# must VERB
# somehow ADV
# make VERB
# the DET
# relay NOUN
# , PUNCT
# inherit VERB
# the DET
# trouble NOUN
# , PUNCT
# and CCONJ
# reinvent VERB
# the DET
# conditions NOUN
# for ADP
# multispecies NOUN
# flourishing VERB
# , PUNCT
# not PART
# just ADV
# in ADP
# a DET
# time NOUN
# of ADP
# ceaseless PROPN
# human ADJ
# wars NOUN
# and CCONJ
# genocides NOUN
# , PUNCT
# but CCONJ
# in ADP
# a DET
# time NOUN
# of ADP
# humanpropelled VERB
# mass NOUN
# extinctions NOUN
# and CCONJ
# multispecies NOUN
# genocides NOUN
# that DET
# sweep VERB
# people NOUN
# and CCONJ
# critters NOUN
# into ADP
# the DET
# vortex NOUN
# . PUNCT
# We PRON
# must VERB
# “ PUNCT
# dare VERB
# ‘ PUNCT
# to PART
# make VERB
# ’ PUNCT
# the DET
# relay NOUN
# ; PUNCT
# that DET
# is AUX
# to PART
# create VERB
# , PUNCT
# to PART
# fabulate VERB
# , PUNCT
# in ADP
# order NOUN
# not PART
# to PART
# despair VERB
# . PUNCT
# In ADP
# order NOUN
# to PART
# induce VERB
# a DET
# transformation NOUN
# , PUNCT
# perhaps ADV
# , PUNCT
# but CCONJ
# without ADP
# the DET
# artificial ADJ
# loyalty NOUN
# that DET
# would VERB
# resemble VERB
# ‘ PUNCT
# in ADP
# the DET
# name NOUN
# of ADP
# a DET
# cause NOUN
# , PUNCT
# ’ PUNCT
# no ADV
# matter ADV
# how ADV
# noble ADJ
# it PRON
# might VERB
# be AUX
# . PUNCT
# ” PUNCT
# Hannah PROPN
# Arendt PROPN
# and CCONJ
# Virginia PROPN
# Woolf PROPN
# both DET
# understood VERB
# the DET
# high ADJ
# stakes NOUN
# of ADP
# training VERB
# the DET
# mind NOUN
# and CCONJ
# imagination NOUN
# to PART
# go VERB
# visiting VERB
# , PUNCT
# to PART
# venture VERB
# off ADP
# the DET
# beaten VERB
# path NOUN
# to PART
# meet VERB
# unexpected ADJ
# , PUNCT
# non ADJ
# - ADJ
# natal ADJ
# kin NOUN
# , PUNCT
# and CCONJ
# to PART
# strike VERB
# up ADP
# conversations NOUN
# , PUNCT
# to PART
# pose VERB
# and CCONJ
# respond VERB
# to ADP
# interesting ADJ
# questions NOUN
# , PUNCT
# to PART
# propose VERB
# together ADV
# something PRON
# unanticipated ADJ
# , PUNCT
# to PART
# take VERB
# up ADP
# the DET
# unasked ADJ
# - PUNCT
# for ADP
# obligations NOUN
# of ADP
# having VERB
# met VERB
# . PUNCT
# This DET
# is AUX
# what PRON
# I PRON
# have AUX
# called VERB
# cultivating VERB
# response NOUN
# - PUNCT
# ability NOUN
# . PUNCT
# Visiting VERB
# is AUX
# not PART
# a DET
# heroic ADJ
# practice NOUN
# ; PUNCT
# making VERB
# a DET
# fuss NOUN
# is AUX
# not PART
# the DET
# Revolution PROPN
# ; PUNCT
# thinking VERB
# with ADP
# each DET
# other ADJ
# is AUX
# not PART
# Thought VERB
# . PUNCT
# Opening VERB
# up ADP
# versions NOUN
# so SCONJ
# stories NOUN
# can VERB
# be AUX
# ongoing ADJ
# is AUX
# so ADV
# mundane ADJ
# , PUNCT
# so ADV
# earth NOUN
# - PUNCT
# bound VERB
# . PUNCT
# That DET
# is AUX
# precisely ADV
# the DET
# point NOUN
# . PUNCT
# The DET
# blackbird NOUN
# sings VERB
# its DET
# importance NOUN
# ; PUNCT
# the DET
# babblers NOUN
# dance VERB
# their DET
# shining VERB
# prestige NOUN
# ; PUNCT
# the DET
# storytellers NOUN
# crack VERB
# the DET
# established ADJ
# disorder NOUN
# . PUNCT
# That DET
# is AUX
# what PRON
# “ PUNCT
# going VERB
# too ADV
# far ADV
# ” PUNCT
# means VERB
# , PUNCT
# and CCONJ
# this DET
# curious ADJ
# practice NOUN
# is AUX
# not PART
# safe ADJ
# . PUNCT
# Like SCONJ
# Arendt PROPN
# and CCONJ
# Woolf PROPN
# , PUNCT
# Despret PROPN
# and CCONJ
# her DET
# collaborators NOUN
# understand VERB
# that SCONJ
# we PRON
# are AUX
# dealing VERB
# with ADP
# “ PUNCT
# the DET
# idea NOUN
# of ADP
# a DET
# world NOUN
# that DET
# could VERB
# be AUX
# habitable ADJ
# . PUNCT
# ” PUNCT
# “ PUNCT
# The DET
# very ADJ
# strength NOUN
# of ADP
# women NOUN
# who PRON
# make VERB
# a DET
# fuss NOUN
# is AUX
# not PART
# to PART
# represent VERB
# the DET
# True ADJ
# , PUNCT
# rather ADV
# to PART
# be AUX
# witnesses NOUN
# for ADP
# the DET
# possibility NOUN
# of ADP
# other ADJ
# ways NOUN
# of ADP
# doing VERB
# what PRON
# would VERB
# perhaps ADV
# be AUX
# ‘ PUNCT
# better ADJ
# . PUNCT
# ’ PUNCT
# The DET
# fuss NOUN
# is AUX
# not PART
# the DET
# heroic ADJ
# statement NOUN
# of ADP
# a DET
# grand ADJ
# cause NOUN
# . PUNCT
# . PUNCT
# . PUNCT
# It PRON
# instead ADV
# affirms VERB
# the DET
# need NOUN
# to PART
# resist VERB
# the DET
# stifling VERB
# impotence NOUN
# created VERB
# by ADP
# the DET
# ‘ PUNCT
# no DET
# possibility NOUN
# to PART
# do AUX
# otherwise ADV
# , PUNCT
# whether SCONJ
# we PRON
# want VERB
# it PRON
# or CCONJ
# not PART
# , PUNCT
# ’ PUNCT
# which DET
# now ADV
# reigns VERB
# everywhere ADV
# . PUNCT
# ” PUNCT
# It PRON
# is AUX
# past ADJ
# time NOUN
# to PART
# make VERB
# such DET
# a DET
# fuss NOUN
# . PUNCT
# Despret PROPN
# ’s PART
# curious ADJ
# practice NOUN
# has AUX
# no DET
# truck NOUN
# with ADP
# loyalty NOUN
# to ADP
# a DET
# cause NOUN
# or CCONJ
# doctrine NOUN
# ; PUNCT
# but CCONJ
# it PRON
# draws VERB
# deeply ADV
# from ADP
# another DET
# virtue NOUN
# that DET
# is AUX
# sometimes ADV
# confused VERB
# with ADP
# loyalty NOUN
# , PUNCT
# namely ADV
# , PUNCT
# “ PUNCT
# thinking VERB
# from ADP
# ” PUNCT
# a DET
# heritage NOUN
# . PUNCT
# She PRON
# is AUX
# tuned VERB
# to ADP
# the DET
# obligations NOUN
# that DET
# inhere VERB
# in ADP
# starting VERB
# from ADP
# situated VERB
# histories NOUN
# , PUNCT
# situated VERB
# stories NOUN
# . PUNCT
# She PRON
# retells VERB
# the DET
# parable NOUN
# of ADP
# the DET
# twelve NUM
# camels NOUN
# in ADP
# order NOUN
# to PART
# tease VERB
# out ADP
# what PRON
# it PRON
# means VERB
# to PART
# “ PUNCT
# start VERB
# from ADP
# , PUNCT
# ” PUNCT
# that ADV
# is ADV
# , PUNCT
# to PART
# “ PUNCT
# remain VERB
# obligated ADJ
# with ADP
# respect NOUN
# to ADP
# that DET
# from ADP
# which DET
# we PRON
# speak VERB
# , PUNCT
# think VERB
# , PUNCT
# or CCONJ
# act VERB
# . PUNCT
# It PRON
# means VERB
# to PART
# let VERB
# ourselves PRON
# learn VERB
# from ADP
# the DET
# event NOUN
# and CCONJ
# to PART
# create VERB
# from ADP
# it PRON
# . PUNCT
# ” PUNCT
# In ADP
# a DET
# sort NOUN
# of ADP
# cat NOUN
# ’s PUNCT
# cradle NOUN
# with ADP
# powerful ADJ
# fables NOUN
# , PUNCT
# Despret PROPN
# received VERB
# the DET
# parable NOUN
# from ADP
# Isabelle PROPN
# Stengers PROPN
# , PUNCT
# and CCONJ
# then ADV
# she PRON
# relayed VERB
# it PRON
# to ADP
# me PRON
# in ADV
# early ADV
# . PUNCT
# I PRON
# relay VERB
# it PRON
# back ADV
# to ADP
# her PRON
# here ADV
# . PUNCT
# To PART
# inherit NOUN
# is AUX
# an DET
# act NOUN
# “ PUNCT
# which DET
# demands VERB
# thought NOUN
# and CCONJ
# commitment NOUN
# . PUNCT
# An DET
# act NOUN
# that DET
# calls VERB
# for ADP
# our DET
# transformation NOUN
# by ADP
# the DET
# very ADJ
# deed NOUN
# of ADP
# inheriting VERB
# . PUNCT
# ” PUNCT
# In ADP
# his DET
# will NOUN
# , PUNCT
# the DET
# father NOUN
# in ADP
# this DET
# story NOUN
# left VERB
# his DET
# three NUM
# quarrelsome NOUN
# sons NOUN
# a DET
# seemingly ADV
# impossible ADJ
# inheritance NOUN
# : PUNCT
# eleven NUM
# camels NOUN
# to PART
# be AUX
# divided VERB
# in ADP
# a DET
# precise ADJ
# way NOUN
# , PUNCT
# half NOUN
# to ADP
# the DET
# eldest ADJ
# son NOUN
# , PUNCT
# a DET
# quarter NOUN
# to ADP
# the DET
# second ADJ
# son NOUN
# , PUNCT
# and CCONJ
# a DET
# sixth ADJ
# to ADP
# the DET
# third ADJ
# . PUNCT
# The DET
# perverse ADJ
# requirements NOUN
# of ADP
# the DET
# legacy NOUN
# provoked VERB
# the DET
# confused ADJ
# sons NOUN
# , PUNCT
# who PRON
# were AUX
# on ADP
# the DET
# verge NOUN
# of ADP
# failing VERB
# to PART
# fulfill VERB
# the DET
# terms NOUN
# of ADP
# the DET
# will NOUN
# , PUNCT
# to PART
# visit VERB
# an DET
# old ADJ
# man NOUN
# living VERB
# in ADP
# the DET
# village NOUN
# . PUNCT
# His DET
# savvy ADJ
# kindness NOUN
# in ADP
# giving VERB
# the DET
# sons NOUN
# a DET
# twelfth ADJ
# camel NOUN
# allowed VERB
# the DET
# heirs NOUN
# to PART
# create VERB
# a DET
# solution NOUN
# to ADP
# their DET
# difficult ADJ
# heritage NOUN
# ; PUNCT
# they PRON
# could VERB
# make VERB
# their DET
# inheritance NOUN
# active ADJ
# , PUNCT
# alive ADJ
# , PUNCT
# generative ADJ
# . PUNCT
# With ADP
# twelve NUM
# camels NOUN
# , PUNCT
# the DET
# fractions NOUN
# worked VERB
# , PUNCT
# and CCONJ
# there PRON
# was AUX
# one NUM
# camel NOUN
# left VERB
# over ADP
# to PART
# give VERB
# back ADV
# to ADP
# the DET
# old ADJ
# man NOUN
# . PUNCT
# Despret ADJ
# notes VERB
# that SCONJ
# the DET
# tale NOUN
# she PRON
# read VERB
# left VERB
# actual ADJ
# camels NOUN
# out SCONJ
# of ADP
# the DET
# enlargement NOUN
# and CCONJ
# creativity NOUN
# of ADP
# finding VERB
# what PRON
# it PRON
# means VERB
# to PART
# “ PUNCT
# start VERB
# from ADP
# . PUNCT
# ” PUNCT
# Those DET
# storied VERB
# camels NOUN
# were AUX
# conventional ADJ
# , PUNCT
# discursive ADJ
# , PUNCT
# figural ADJ
# beasts NOUN
# , PUNCT
# whose DET
# only ADJ
# function NOUN
# was AUX
# to PART
# give VERB
# occasion NOUN
# for ADP
# the DET
# problematic ADJ
# sons NOUN
# to PART
# grow VERB
# in ADP
# patriarchal ADJ
# understanding NOUN
# , PUNCT
# recapitulating VERB
# more ADJ
# than SCONJ
# a DET
# little ADJ
# the DET
# history NOUN
# of ADP
# philosophy NOUN
# that SCONJ
# Despret PROPN
# — PUNCT
# and CCONJ
# I PRON
# — PUNCT
# inherited VERB
# . PUNCT
# But CCONJ
# by ADP
# listening VERB
# , PUNCT
# telling VERB
# , PUNCT
# and CCONJ
# activating VERB
# that DET
# particular ADJ
# story NOUN
# her DET
# way NOUN
# , PUNCT
# she PRON
# makes VERB
# something PRON
# that DET
# was AUX
# absent ADJ
# present ADJ
# . PUNCT
# She PRON
# made VERB
# an DET
# interesting ADJ
# , PUNCT
# curious ADJ
# fuss NOUN
# without ADP
# denouncing VERB
# anybody PRON
# . PUNCT
# Therefore ADV
# , PUNCT
# another DET
# heritage NOUN
# emerges VERB
# and CCONJ
# makes VERB
# claims NOUN
# on ADP
# anyone PRON
# listening VERB
# , PUNCT
# anyone PRON
# attuned VERB
# . PUNCT
# It PRON
# is AUX
# n’t PART
# just ADV
# philosophy NOUN
# that DET
# has AUX
# to PART
# change VERB
# ; PUNCT
# the DET
# mortal ADJ
# world NOUN
# shifts NOUN
# . PUNCT
# Long ADV
# - PUNCT
# legged ADJ
# , PUNCT
# big ADJ
# - PUNCT
# lipped ADJ
# , PUNCT
# humped VERB
# camels NOUN
# shake VERB
# the DET
# dust NOUN
# from ADP
# their DET
# hot ADJ
# , PUNCT
# hard ADJ
# - PUNCT
# worked ADJ
# hides NOUN
# and CCONJ
# nuzzle VERB
# the DET
# storyteller NOUN
# for ADP
# a DET
# scratch NOUN
# behind ADP
# the DET
# ears NOUN
# . PUNCT
# Despret PROPN
# , PUNCT
# and CCONJ
# because SCONJ
# of ADP
# her PRON
# , PUNCT
# we PRON
# , PUNCT
# inherit NOUN
# camels NOUN
# now ADV
# , PUNCT
# camels NOUN
# with ADP
# their DET
# people NOUN
# , PUNCT
# in ADP
# their DET
# markets NOUN
# and CCONJ
# places NOUN
# of ADP
# travel NOUN
# and CCONJ
# labor NOUN
# , PUNCT
# in ADP
# their DET
# living NOUN
# and CCONJ
# dying VERB
# in ADP
# worlds NOUN
# - PUNCT
# at ADP
# - PUNCT
# stake NOUN
# , PUNCT
# like SCONJ
# the DET
# contemporary ADJ
# Gobi PROPN
# Desert PROPN
# . PUNCT
# We PRON
# start VERB
# from ADP
# what PRON
# is AUX
# henceforth ADV
# a DET
# dilated VERB
# story NOUN
# that DET
# makes VERB
# unexpected ADJ
# demands NOUN
# to PART
# cultivate VERB
# response NOUN
# - PUNCT
# ability NOUN
# . PUNCT
# If SCONJ
# we PRON
# are AUX
# to PART
# remain VERB
# faithful ADJ
# to ADP
# starting VERB
# from ADP
# the DET
# transformed VERB
# story NOUN
# , PUNCT
# we PRON
# can VERB
# no ADV
# longer ADV
# not PART
# know VERB
# or CCONJ
# not PART
# care VERB
# that SCONJ
# camels NOUN
# and CCONJ
# people NOUN
# are AUX
# at ADP
# stake NOUN
# to ADP
# each DET
# other ADJ
# — PUNCT
# across ADP
# regions NOUN
# , PUNCT
# genders NOUN
# , PUNCT
# races NOUN
# , PUNCT
# species NOUN
# , PUNCT
# practices NOUN
# . PUNCT
# From ADP
# now ADV
# on ADV
# , PUNCT
# call VERB
# that DET
# philosophy NOUN
# , PUNCT
# a DET
# game NOUN
# of ADP
# cat NOUN
# ’s PROPN
# cradle NOUN
# , PUNCT
# not PART
# a DET
# lineage NOUN
# . PUNCT
# We PRON
# are AUX
# obligated ADJ
# to PART
# speak VERB
# from ADP
# situated ADJ
# worlds NOUN
# , PUNCT
# but CCONJ
# we PRON
# no ADV
# longer ADV
# need VERB
# start NOUN
# from ADP
# a DET
# humanist ADJ
# patriline NOUN
# and CCONJ
# its DET
# breath NOUN
# - PUNCT
# taking VERB
# erasures NOUN
# and CCONJ
# high ADJ
# - PUNCT
# wire NOUN
# acts NOUN
# . PUNCT
# The DET
# risk NOUN
# of ADP
# listening VERB
# to ADP
# a DET
# story NOUN
# is AUX
# that SCONJ
# it PRON
# can VERB
# obligate VERB
# us PRON
# in ADP
# ramifying VERB
# webs NOUN
# that DET
# can VERB
# not PART
# be AUX
# known VERB
# in ADP
# advance NOUN
# of ADP
# venturing VERB
# among ADP
# their DET
# myriad ADJ
# threads NOUN
# . PUNCT
# In ADP
# a DET
# world NOUN
# of ADP
# anthropozoogenesis NOUN
# , PUNCT
# the DET
# figural NOUN
# is AUX
# more ADV
# likely ADJ
# than SCONJ
# not PART
# to PART
# grow VERB
# teeth NOUN
# and CCONJ
# bite VERB
# us PRON
# in ADP
# the DET
# bum NOUN
# . PUNCT
# Despret PROPN
# ’s PART
# philosophical ADJ
# ethology NOUN
# starts VERB
# from ADP
# the DET
# dead ADJ
# and CCONJ
# missing ADJ
# as ADV
# well ADV
# as SCONJ
# from ADP
# the DET
# living NOUN
# and CCONJ
# visible ADJ
# . PUNCT
# She PRON
# has AUX
# studied VERB
# situated VERB
# human ADJ
# beings NOUN
# ’ PART
# mourning NOUN
# practices NOUN
# for ADP
# their DET
# dead ADJ
# in ADP
# ways NOUN
# strongly ADV
# akin ADJ
# to ADP
# her DET
# practice NOUN
# of ADP
# philosophical ADJ
# ethology NOUN
# ; PUNCT
# in ADP
# both DET
# domains NOUN
# , PUNCT
# she PRON
# attends VERB
# to ADP
# how ADV
# — PUNCT
# in ADP
# practice NOUN
# — PUNCT
# people NOUN
# can VERB
# and CCONJ
# do AUX
# solicit VERB
# the DET
# absent NOUN
# into ADP
# vivid ADJ
# copresence NOUN
# , PUNCT
# in ADP
# many ADJ
# kinds NOUN
# of ADP
# temporality NOUN
# and CCONJ
# materiality NOUN
# . PUNCT
# She PRON
# attends VERB
# to ADP
# how ADV
# practices NOUN
# — PUNCT
# activated VERB
# storytelling NOUN
# — PUNCT
# can VERB
# be AUX
# on ADP
# the DET
# side NOUN
# of ADP
# what PRON
# I PRON
# call VERB
# “ PUNCT
# ongoingness NOUN
# ” PUNCT
# : PUNCT
# that ADV
# is AUX
# , PUNCT
# nurturing VERB
# , PUNCT
# or CCONJ
# inventing VERB
# , PUNCT
# or CCONJ
# discovering VERB
# , PUNCT
# or CCONJ
# somehow ADV
# cobbling VERB
# together ADV
# ways NOUN
# for ADP
# living NOUN
# and CCONJ
# dying VERB
# well ADV
# with ADP
# each DET
# other ADJ
# in ADP
# the DET
# tissues NOUN
# of ADP
# an DET
# earth NOUN
# whose DET
# very ADJ
# habitability NOUN
# is AUX
# threatened VERB
# . PUNCT
# Many ADJ
# kinds NOUN
# of ADP
# failure NOUN
# of ADP
# ongoingness ADJ
# crumble ADJ
# lifeways NOUN
# in ADP
# our DET
# times NOUN
# of ADP
# onrushing VERB
# extinctions NOUN
# , PUNCT
# exterminations NOUN
# , PUNCT
# wars NOUN
# , PUNCT
# extractions NOUN
# , PUNCT
# and CCONJ
# genocides NOUN
# . PUNCT
# Many ADJ
# kinds NOUN
# of ADP
# absence NOUN
# , PUNCT
# or CCONJ
# threatened VERB
# absence NOUN
# , PUNCT
# must VERB
# be AUX
# brought VERB
# into ADP
# ongoing ADJ
# response NOUN
# - PUNCT
# ability NOUN
# , PUNCT
# not PART
# in ADP
# the DET
# abstract ADJ
# but CCONJ
# in ADP
# homely ADV
# storied VERB
# cultivated VERB
# practice NOUN
# . PUNCT
# To ADP
# my DET
# initial ADJ
# surprise NOUN
# , PUNCT
# this DET
# matter NOUN
# brought VERB
# Despret PROPN
# and CCONJ
# me PRON
# together ADV
# with ADP
# racing NOUN
# pigeons NOUN
# , PUNCT
# also ADV
# called VERB
# carrier NOUN
# pigeons NOUN
# ( PUNCT
# in ADP
# French ADJ
# voyageurs NOUN
# ) PUNCT
# and CCONJ
# with ADP
# their DET
# avid ADJ
# fanciers NOUN
# ( PUNCT
# in ADP
# French ADJ
# colombophiles NOUN
# , PUNCT
# lovers NOUN
# of ADP
# pigeons NOUN
# ) PUNCT
# . PUNCT
# I PRON
# wrote VERB
# an DET
# essay NOUN
# for ADP
# Despret PROPN
# after ADP
# an DET
# extraordinary ADJ
# week NOUN
# with ADP
# her PRON
# and CCONJ
# her DET
# colleagues NOUN
# in ADP
# the DET
# chateau NOUN
# at ADP
# Cerisy PROPN
# in ADP
# July PROPN
# , PUNCT
# in ADP
# which DET
# I PRON
# proposed VERB
# playing VERB
# string NOUN
# figure NOUN
# games NOUN
# with ADP
# companion NOUN
# species NOUN
# for ADP
# cultivating VERB
# multispecies NOUN
# response NOUN
# - PUNCT
# ability NOUN
# . PUNCT
# I PRON
# sent VERB
# Despret PROPN
# a DET
# draft NOUN
# containing VERB
# my DET
# discussion NOUN
# of ADP
# the DET
# wonderful ADJ
# art NOUN
# - PUNCT
# technology NOUN
# - PUNCT
# environmental ADJ
# - PUNCT
# activist NOUN
# project NOUN
# by ADP
# Beatriz PROPN
# da PROPN
# Costa PROPN
# called VERB
# PigeonBlog PROPN
# , PUNCT
# as ADV
# well ADV
# as SCONJ
# a DET
# discussion NOUN
# of ADP
# the DET
# communities NOUN
# of ADP
# racing VERB
# pigeons NOUN
# and CCONJ
# their DET
# fanciers NOUN
# in ADP
# Southern PROPN
# California PROPN
# . PUNCT
# Pigeon PROPN
# racing NOUN
# is AUX
# a DET
# working VERB
# - PUNCT
# class NOUN
# men NOUN
# ’s PART
# sport NOUN
# around ADP
# the DET
# world NOUN
# , PUNCT
# one NUM
# made VERB
# immensely ADV
# difficult ADJ
# in ADP
# conditions NOUN
# of ADP
# urban ADJ
# war NOUN
# ( PUNCT
# Baghdad PROPN
# , PUNCT
# Damascus PROPN
# ) PUNCT
# , PUNCT
# racial ADJ
# and CCONJ
# economic ADJ
# injustice NOUN
# ( PUNCT
# New PROPN
# York PROPN
# , PUNCT
# Berlin PROPN
# ) PUNCT
# , PUNCT
# and CCONJ
# displaced VERB
# labor NOUN
# and CCONJ
# play NOUN
# of ADP
# many ADJ
# kinds NOUN
# across ADP
# regions NOUN
# ( PUNCT
# France PROPN
# , PUNCT
# Iran PROPN
# , PUNCT
# California PROPN
# ) PUNCT
# . PUNCT
# I PRON
# care VERB
# about ADP
# art NOUN
# - PUNCT
# design NOUN
# - PUNCT
# activist NOUN
# practices NOUN
# that DET
# join VERB
# diverse ADJ
# people NOUN
# and CCONJ
# varied ADJ
# critters NOUN
# in ADP
# shared VERB
# , PUNCT
# often ADV
# vexed VERB
# public ADJ
# spaces NOUN
# . PUNCT
# “ PUNCT
# Starting VERB
# from ADP
# ” PUNCT
# this DET
# caring NOUN
# , PUNCT
# not PART
# from ADP
# some DET
# delusional ADJ
# caring NOUN
# in ADP
# general ADJ
# , PUNCT
# landed VERB
# me PRON
# in ADP
# innovative ADJ
# pigeon NOUN
# lofts NOUN
# , PUNCT
# where ADV
# , PUNCT
# it PRON
# turned VERB
# out ADP
# , PUNCT
# Despret PROPN
# , PUNCT
# attuned VERB
# to ADP
# practices NOUN
# of ADP
# commemoration NOUN
# , PUNCT
# had AUX
# already ADV
# begun VERB
# to PART
# roost VERB
# . PUNCT
# In ADP
# particular ADJ
# , PUNCT
# by ADP
# leading VERB
# me PRON
# to ADP
# Matali PROPN
# Crasset PROPN
# ’s PART
# Capsule PROPN
# , PUNCT
# built VERB
# in ADP
# in ADP
# the DET
# leisure NOUN
# park NOUN
# of ADP
# Caudry PROPN
# , PUNCT
# she PRON
# shared VERB
# her DET
# understanding NOUN
# of ADP
# the DET
# power NOUN
# of ADP
# holding VERB
# open ADJ
# actual ADJ
# space NOUN
# for ADP
# ongoing ADJ
# living NOUN
# and CCONJ
# working VERB
# in ADP
# the DET
# face NOUN
# of ADP
# threatened ADJ
# absence NOUN
# as SCONJ
# a DET
# potent ADJ
# practice NOUN
# of ADP
# commemoration NOUN
# . PUNCT
# The DET
# Beauvois PROPN
# association NOUN
# of ADP
# carrier PROPN
# pigeon PROPN
# fanciers NOUN
# asked VERB
# Crasset PROPN
# , PUNCT
# an DET
# artist NOUN
# and CCONJ
# industrial ADJ
# designer NOUN
# , PUNCT
# to PART
# build VERB
# a DET
# prototype NOUN
# pigeon NOUN
# loft NOUN
# that DET
# would VERB
# combine VERB
# beauty NOUN
# , PUNCT
# functionality NOUN
# for ADP
# people NOUN
# and CCONJ
# birds NOUN
# , PUNCT
# and CCONJ
# a DET
# pedagogic ADJ
# lure NOUN
# to PART
# draw VERB
# future ADJ
# practitioners NOUN
# into ADP
# learning VERB
# demanding ADJ
# skills NOUN
# . PUNCT
# Actual ADJ
# pigeons NOUN
# had AUX
# to PART
# thrive VERB
# inhabiting VERB
# this DET
# loft NOUN
# ; PUNCT
# actual ADJ
# colombophiles NOUN
# had AUX
# to PART
# experience VERB
# the DET
# loft NOUN
# working VERB
# ; PUNCT
# and CCONJ
# actual ADJ
# visitors NOUN
# to ADP
# the DET
# ecological ADJ
# park NOUN
# , PUNCT
# which DET
# was AUX
# rehabilitating VERB
# exhausted VERB
# farmland NOUN
# into ADP
# a DET
# variegated VERB
# nature NOUN
# reserve NOUN
# for ADP
# recuperating VERB
# critters NOUN
# and CCONJ
# people NOUN
# , PUNCT
# had AUX
# to PART
# be AUX
# infected VERB
# with ADP
# the DET
# desire NOUN
# for ADP
# a DET
# life NOUN
# transformed VERB
# with ADP
# avian ADJ
# voyageurs NOUN
# . PUNCT
# Despret PROPN
# understood VERB
# that SCONJ
# the DET
# prototype NOUN
# , PUNCT
# the DET
# memorial NOUN
# , PUNCT
# had AUX
# to PART
# be AUX
# for ADP
# both CCONJ
# the DET
# carrier NOUN
# pigeons NOUN
# and CCONJ
# their DET
# people NOUN
# — PUNCT
# past ADJ
# , PUNCT
# present ADJ
# and CCONJ
# yet ADV
# to PART
# come VERB
# . PUNCT
# Neither CCONJ
# the DET
# critters NOUN
# nor CCONJ
# the DET
# people NOUN
# could VERB
# have AUX
# existed VERB
# or CCONJ
# could VERB
# endure VERB
# without ADP
# each DET
# other ADJ
# in ADP
# ongoing ADJ
# , PUNCT
# curious ADJ
# practices NOUN
# . PUNCT
# Attached VERB
# to ADP
# ongoing ADJ
# pasts NOUN
# , PUNCT
# they PRON
# bring VERB
# each DET
# other ADJ
# forward ADV
# in ADP
# thick ADJ
# presents NOUN
# and CCONJ
# still ADV
# possible ADJ
# futures NOUN
# ; PUNCT
# they PRON
# stay VERB
# with ADP
# the DET
# trouble NOUN
# in ADP
# speculative ADJ
# fabulation NOUN
# . PUNCT

# %%
entities=[(i, i.label_, i.label) for i in script_doc.ents]
entities
# Out:
# [(Vinciane Despret, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (one morning, 'TIME', 392),
#  (Despret, 'PERSON', 380),
#  (Thelma Rowell, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (Arendt, 'PERSON', 380),
#  (first, 'ORDINAL', 396),
#  (Despret, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (Manners, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (Negev, 'GPE', 384),
#  (Israeli, 'NORP', 381),
#  (Amotz Zahavi, 'PERSON', 380),
#  (Arabian, 'NORP', 381),
#  (Zahavi, 'PERSON', 380),
#  (Zahavi, 'NORP', 381),
#  (Zahavi, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (Israeli, 'NORP', 381),
#  (Despret, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (Jocelyne Porcher, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (Porcher, 'PERSON', 380),
#  (French, 'NORP', 381),
#  (daily, 'DATE', 391),
#  (Despret, 'PERSON', 380),
#  (Porcher, 'PERSON', 380),
#  (first, 'ORDINAL', 396),
#  (nourish, 'NORP', 381),
#  (nourish, 'NORP', 381),
#  (daily, 'DATE', 391),
#  (Despret, 'PERSON', 380),
#  (Isabelle Stengers, 'NORP', 381),
#  (Vinciane Despret, 'PERSON', 380),
#  (Virginia, 'GPE', 384),
#  (Three, 'CARDINAL', 397),
#  (Virginia Woolf, 'PERSON', 380),
#  (Hannah Arendt, 'PERSON', 380),
#  (Virginia, 'GPE', 384),
#  (Revolution, 'EVENT', 387),
#  (blackbird, 'ORDINAL', 396),
#  (Arendt, 'PERSON', 380),
#  (Woolf, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (True, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (twelve, 'CARDINAL', 397),
#  (Despret, 'PERSON', 380),
#  (Isabelle Stengers, 'NORP', 381),
#  (three, 'CARDINAL', 397),
#  (eleven, 'CARDINAL', 397),
#  (half, 'CARDINAL', 397),
#  (a quarter, 'DATE', 391),
#  (second, 'ORDINAL', 396),
#  (sixth, 'ORDINAL', 396),
#  (third, 'ORDINAL', 396),
#  (savvy kindness, 'PERSON', 380),
#  (twelfth, 'ORDINAL', 396),
#  (twelve, 'CARDINAL', 397),
#  (one, 'CARDINAL', 397),
#  (Despret, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (Gobi Desert, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (Despret, 'PERSON', 380),
#  (French, 'NORP', 381),
#  (French, 'NORP', 381),
#  (Despret, 'PERSON', 380),
#  (an extraordinary week, 'DATE', 391),
#  (Cerisy, 'ORG', 383),
#  (July, 'DATE', 391),
#  (Despret, 'PERSON', 380),
#  (Beatriz da Costa, 'ORG', 383),
#  (PigeonBlog, 'ORG', 383),
#  (Southern California, 'LOC', 385),
#  (Baghdad, 'GPE', 384),
#  (Damascus, 'GPE', 384),
#  (New York, 'GPE', 384),
#  (Berlin, 'GPE', 384),
#  (France, 'GPE', 384),
#  (Iran, 'GPE', 384),
#  (California, 'GPE', 384),
#  (Despret, 'PERSON', 380),
#  (Matali Crasset’s Capsule, 'PERSON', 380),
#  (Caudry, 'GPE', 384),
#  (The Beauvois association of carrier pigeon, 'ORG', 383),
#  (Crasset, 'GPE', 384),
#  (Despret, 'PERSON', 380)]

# %%
import csv
with open('spacy_ch7.csv', 'w') as f:
      
    # using csv.writer method from CSV package
    write = csv.writer(f)
      
    write.writerows(entities)
